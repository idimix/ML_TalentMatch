# %%
PATH = '..'
DATA_SOURCE = f'{PATH}/data/source'
DATA_PROCESSED = f'{PATH}/data/processed'

# %%
import os
import pandas as pd
import numpy as np
import polars as pl
from IPython.display import display, Markdown
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import json
from itertools import product

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %% [markdown]
# # case_2_reference_without_resume_sorted

# %%
with open(f'{DATA_SOURCE}/case_2_reference_without_resume_sorted.json') as f:
    case_2_reference_without_resume_sorted = json.load(f)

# %%
case_2_reference_without_resume_sorted.keys()
# Out:
# dict_keys(['vacancy', 'resumes'])

# %%
vacancy_test = pd.Series(case_2_reference_without_resume_sorted['vacancy'])

# %%
vacancy_test
# Out:
# uuid                        8b9c8d16-c7f0-38a2-b80c-d94030c15a6f
# name                                            Java разработчик
# keywords                  Kafka, Java, RxJava, Hystrix, MongoDB
# description    Требования: 4+ года опыта работы с Java 8+ или...
# comment                                                     None
# dtype: object

# %%
resume_test = pd.DataFrame(case_2_reference_without_resume_sorted['resumes'])

# %%
resume_test.sample(3).T
# Out:
#                                                                94  \
# uuid                         0fe70aee-589a-3ba7-8479-d8f2f83b0921
# first_name                                               Вениамин
# last_name                                                   Фомин
# birth_date                                             1986-01-16
# country                                                    Россия
# city                                                       Москва
# about            Креативен – не редко, пытаюсь взглянуть на пр...
# key_skills      Spring Framework, Hibernate ORM, SQL, PostgreS...
# experienceItem  [{'starts': '2023-01-01', 'ends': None, 'emplo...
# languageItems                               [Русский, Английский]
# educationItem                                                 NaN
# languageItem                                                  NaN
#
#                                                                25  \
# uuid                         42eae4bf-4826-3105-b197-dc0afb063714
# first_name                                              Станислав
# last_name                                                Ситников
# birth_date                                             1992-01-24
# country                                                    Россия
# city                                                         Сочи
# about            В 2018 году я сменил профессию. Причиной этог...
# key_skills      Git Java Spring Framework Apache Maven Spring ...
# experienceItem  [{'starts': '2021-11-28', 'ends': None, 'emplo...
# languageItems                                                 NaN
# educationItem   [{'year': 2014, 'organization': 'Сибирская гос...
# languageItem                                [Английский, Русский]
#
#                                                                49
# uuid                         c83fb1c9-2b90-3dab-9d53-05a883e3e0b7
# first_name                                                   Олег
# last_name                                                  Орлова
# birth_date                                             1992-10-04
# country                                                    Россия
# city                                              Санкт-Петербург
# about                                                        None
# key_skills      Java, Kotlin, Spring Framework (MVC, Data), Sp...
# experienceItem  [{'starts': '2023-11-01', 'ends': '2024-01-06'...
# languageItems                                                 NaN
# educationItem   [{'year': 2018, 'organization': 'МГТУ Им. Баум...
# languageItem                                [Русский, Английский]

# %% [markdown]
# # case_2_data_for_members

# %%
case_2_data_for_members = pd.read_json(f'{DATA_SOURCE}/case_2_data_for_members.json')

# %%
case_2_data_for_members.head()
# Out:
#                                              vacancy  \
# 0  {'uuid': '779f3a59-206a-3241-adc4-d7db504f960b...
# 1  {'uuid': '7a4813fc-43bc-3896-a607-4c8682b01002...
# 2  {'uuid': 'c03085c3-9b1e-3564-bb1e-59aa72e5fbca...
# 3  {'uuid': 'a8dd83c3-178d-3c70-90c2-7c3648f6b96a...
# 4  {'uuid': '9d98eba0-13bb-38d3-b742-4fd445954b3d...
#
#                                       failed_resumes  \
# 0  [{'uuid': '74392e00-ecfb-335b-9fc1-c2652dca06e...
# 1  [{'uuid': '254487e1-81ba-3f2b-9f15-eba98d891ef...
# 2  [{'uuid': '8746a855-022c-34d4-9b55-58da5483c25...
# 3  [{'uuid': '557c9b5b-9707-360b-bb1f-18c3c1b9439...
# 4  [{'uuid': '821b6466-f3e2-37c9-b44f-676d91bde04...
#
#                                    confirmed_resumes
# 0  [{'uuid': '8c8cf797-2c6b-3f4b-b28b-20d57bd88b8...
# 1  [{'uuid': '23ca55a4-2257-3cbc-a34f-d5e1b98d8c2...
# 2  [{'uuid': '95cd87f6-0495-36e5-adad-0782a1ac435...
# 3  [{'uuid': '077836a8-16a8-34f1-a192-fe82ebc8bc9...
# 4  [{'uuid': '2e517375-ff7d-3781-ae5c-2b0784dbc2b...

# %% [markdown]
# ## Вакансии

# %%
# получение датафрейма вакансий
df_vacancy = pd.DataFrame.from_records(case_2_data_for_members['vacancy'])
df_vacancy = df_vacancy.append(vacancy_test, ignore_index=True)
df_vacancy = df_vacancy.rename({'name': 'title'}, axis=1)
df_vacancy['title'] = df_vacancy['title'].str.strip()
df_vacancy.to_pickle(f'{DATA_PROCESSED}/df_vacancy.pickle')
# Out:
# /tmp/ipykernel_41563/1607377407.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_vacancy = df_vacancy.append(vacancy_test, ignore_index=True)

# %%
df_vacancy.sample(3).T
# Out:
#                                                             11  \
# uuid                      dfaf7cc8-3726-361e-b7cf-6d9746d6bf77
# title                                              Тестировщик
# keywords                                                  None
# description   Грейд до 13 МСК/СПБ - 283000 Регионы - 233500...
# comment                                                   None
#
#                                                             6   \
# uuid                      a8f56ed3-3ef3-365d-ade4-2df4db5d4af8
# title                       Системный аналитик комманда Залоги
# keywords                                                  None
# description   Стрим занимается системой управления залогами...
# comment                                                   None
#
#                                                             9
# uuid                      01713376-e04d-3f9d-9287-7a5ff74918c3
# title                                Системный аналитик финтех
# keywords                                                  None
# description   Системный аналитик (14 грейд middle, 15 грейд...
# comment                                                   None

# %% [markdown]
# ## Резюме

# %%
def transform_resume(df_resume):
    df_resume = df_resume.copy()
    
    if 'languageItems' in df_resume.columns and 'languageItem' in df_resume.columns:
        df_resume['language'] = df_resume['languageItems'].fillna(df_resume['languageItem'])
    elif 'languageItems' in df_resume.columns:
        df_resume['language'] = df_resume['languageItems']
    else:
        df_resume['language'] = df_resume['languageItem']
        

    df_postions = df_resume \
        .set_index('uuid')['experienceItem'] \
        .explode() \
        .apply(pd.Series) \
        .reset_index()
    df_postions['position'] = df_postions['position'].str.strip()
    df_postions['description'] = df_postions['description'].str.strip()

    df_postions['ends'] = df_postions['ends'].fillna(df_postions['ends'].dropna().max())
    df_postions['starts'] = df_postions['starts'].fillna(df_postions['starts'].dropna().min())
    #df_postions = df_postions[~df_postions['starts'].isna()]
    df_postions['starts'] = pd.to_datetime(df_postions['starts'])
    df_postions['ends'] = pd.to_datetime(df_postions['ends'])
    df_postions['days'] = (df_postions['ends'] - df_postions['starts']).dt.days

    # description
    description = df_postions.groupby('uuid')['description'].agg(lambda x: '. \n'.join(x.fillna('').str.strip().tolist()))
    df_resume['all_description'] = df_resume['uuid'].map(description)

    # days
    days = df_postions.groupby('uuid').agg({'days': ['min', 'max', 'mean']})
    days.columns = [f'{c1}_{c2}' for c1, c2 in days.columns]
    days = days.reset_index()
    df_resume = df_resume.merge(days, on='uuid')

    # last
    df_postions['last_fl'] = df_postions['starts'] == df_postions.groupby('uuid')['starts'].transform('max')
    last = df_postions.query('last_fl').drop_duplicates(subset='uuid', keep='first')
    df_resume['last_description'] = df_resume['uuid'].map(last.set_index('uuid')['description'])
    df_resume['last_days'] = df_resume['uuid'].map(last.set_index('uuid')['days'])

    df_postions = df_postions.query('position != ""')
    df_postions['last_fl'] = df_postions['starts'] == df_postions.groupby('uuid')['starts'].transform('max')
    last = df_postions.query('last_fl').drop_duplicates(subset='uuid', keep='first')
    df_resume['title'] = df_resume['uuid'].map(last.set_index('uuid')['position']).fillna('')

    # education
    education = df_resume \
        .set_index('uuid')['educationItem'] \
        .explode() \
        .apply(pd.Series) \
        .drop(0, axis=1) \
        .reset_index() \
        .fillna('')
    clms = ['organization', 'faculty', 'specialty', 'result', 'education_level']
    education = education.groupby('uuid')[clms].agg(lambda x: '. '.join(x.str.strip().tolist()))
    education = education.agg(lambda x: '. '.join(x.tolist()), axis=1)
    for i in range(100):
        education = education.str.replace('\.\.', '.').replace('\. \.', '\.').str.replace('\. \.', '.')
    df_resume['education'] = df_resume['uuid'].map(education)
    df_resume = df_resume.drop(['experienceItem', 'educationItem'], axis=1)


    clms = ['all_description', 'key_skills', 'education', 'language']
    for col in clms:
        df_resume[col] = df_resume[col].fillna('')
    df_resume['description'] = df_resume.apply(lambda x: '. \n'.join([str(x[col]) for col in clms if x[col] != '']), axis=1)
    
    return df_resume

# %%
failed_resumes = pd.DataFrame.from_records(case_2_data_for_members['failed_resumes'].explode().values)
confirmed_resumes = pd.DataFrame.from_records(case_2_data_for_members['confirmed_resumes'].explode().values)

failed_resumes = transform_resume(failed_resumes)
confirmed_resumes = transform_resume(confirmed_resumes)
resume_test = transform_resume(resume_test)
# Out:
# /tmp/ipykernel_41563/2730555251.py:60: FutureWarning: The default value of regex will change from True to False in a future version.
#   education = education.str.replace('\.\.', '.').replace('\. \.', '\.').str.replace('\. \.', '.')
# /tmp/ipykernel_41563/2730555251.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_postions['last_fl'] = df_postions['starts'] == df_postions.groupby('uuid')['starts'].transform('max')
# /tmp/ipykernel_41563/2730555251.py:60: FutureWarning: The default value of regex will change from True to False in a future version.
#   education = education.str.replace('\.\.', '.').replace('\. \.', '\.').str.replace('\. \.', '.')
# /tmp/ipykernel_41563/2730555251.py:60: FutureWarning: The default value of regex will change from True to False in a future version.
#   education = education.str.replace('\.\.', '.').replace('\. \.', '\.').str.replace('\. \.', '.')

# %%
resume_test['title'].unique()
# Out:
# array(['Team Lead (Senior Java Developer)', 'Senior Java Developer',
#        'Ведущий java разработчик', 'Ведущий разработчик',
#        'Senior Backend Devloper', 'Java Software Engineer',
#        'Senior java developer', 'Java-разработчик',
#        'Java Software Developer',
#        'Старший программист-разработчик Kotlin + Java',
#        'Старший Java-разработчик', 'Ведущий инженер-программист',
#        'Java Developer', 'Senior Software Developer Team Lead',
#        'Senior Java Software Engineer', 'tech expert',
#        'Главный инженер по разработке', 'Разработчик', 'Java разработчик',
#        'Программист-разработчик', 'Senior java разработчик',
#        'Middle Java Developer', 'Team Lead Java разработчик',
#        'Старший разработчик', 'Team/Tech Lead, Senior Software Engineer',
#        'Java/Kotlin Developer', 'Senior Backend Developer',
#        'Старший инженер', 'Backend developer', 'Backend Tech Lead',
#        'senior java developer', 'Software Engineer',
#        'Lead backend developer', 'Lead Software Engineer',
#        'Java developer', 'Руководитель IT-департамента',
#        'Senior Backend Engineer/Tech Lead', 'Software engineer',
#        'Разработчик Java', 'Backend Team Lead', 'Системный архитектор',
#        'Senior Java developer', 'Ведущий разработчик Java/Kotlin',
#        'Team Lead', 'Java/Kotlin разработчик / Fullstack разработчик',
#        'Java-Developer', 'Middle Java developer (Java,JS)',
#        'Старший разработчик программного обеспечения',
#        'Backend developer Инвестор', 'Инженер-программист Java',
#        'Senior Java Software Engineer, Assistant Vice President',
#        'Ведущий Java разработчик', 'Ведущий инженер', 'Программист',
#        'Программист Java', 'Старший Java разработчик'], dtype=object)

# %%
df_resume = pd.concat([
    failed_resumes, 
    confirmed_resumes, 
    resume_test,
], sort=False, ignore_index=True)

# одно такое найдено
mask = df_resume['title'] == ''
df_resume.loc[mask, 'title'] = 'Системный аналитик'

# save
df_resume.to_pickle(f'{DATA_PROCESSED}/df_resume.pickle')

# %%
df_resume.sample(3).T
# Out:
#                                                                 584  \
# uuid                           72e10137-dbd8-373c-a6aa-3babc25a20f2
# first_name                                                  Варвара
# last_name                                                    Блинов
# birth_date                                               1995-08-02
# country                                                      Россия
# city                                                         Москва
# about             Увлекаюсь программированием, постоянно стараюс...
# key_skills
# languageItems                                                   NaN
# language                                      [Русский, Английский]
# all_description   Разработка программного кода на ГП, архитектур...
# days_min                                                        639
# days_max                                                        660
# days_mean                                                648.666667
# last_description  Разработка программного кода на ГП, архитектур...
# last_days                                                       660
# title                                       Ведущий ETL-разработчик
# education         Московский авиационный институт (национальный ...
# description       Разработка программного кода на ГП, архитектур...
# languageItem                                  [Русский, Английский]
#
#                                                                 466  \
# uuid                           da4c44dd-7c00-3f75-98b4-096b533488a4
# first_name                                                  Изольда
# last_name                                                   Дроздов
# birth_date                                               1996-01-01
# country                                                      Россия
# city
# about              Занимаюсь разработкой бекенда и фронтенда веб...
# key_skills        Kotlin, TypeScript, Java, Vue.js, Spring Boot,...
# languageItems                                                   NaN
# language
# all_description   Обязанности Разработка и проектирование систем...
# days_min                                                        396
# days_max                                                       2585
# days_mean                                                    1490.5
# last_description  Ревью выполняемых заданий и консультации на ку...
# last_days                                                       396
# title                                                     Наставник
# education         ДонНТУ. Компьютерных наук и технологий. Специа...
# description       Обязанности Разработка и проектирование систем...
# languageItem                                                    NaN
#
#                                                                 395
# uuid                           6d2a37b5-5e4e-373d-881a-750af37f8284
# first_name                                                    Павел
# last_name                                                Никифорова
# birth_date                                                     None
# country                                                      Россия
# city                                                         Москва
# about                                                          None
# key_skills        Java 11, Kotlin, Spring Framework (Boot, WebFl...
# languageItems                                                   NaN
# language
# all_description   Проект: Разработка платформы для мониторинга ж...
# days_min                                                        425
# days_max                                                        912
# days_mean                                                618.333333
# last_description  Проект: Разработка платформы для мониторинга ж...
# last_days                                                       912
# title                            Ведущий Java разработчик/Tech Lead
# education         . Магистр, Компьютерные сети и телекоммуникаци...
# description       Проект: Разработка платформы для мониторинга ж...
# languageItem                                                    NaN

# %%
df_resume['uuid'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Обучающая выборка

# %%
# создание обучающей выборки
case_2_data_for_members['uuid_vacancy'] = case_2_data_for_members['vacancy'].str['uuid']

func = lambda x: [item['uuid'] for item in x]
case_2_data_for_members['failed'] = case_2_data_for_members['failed_resumes'].apply(func)
case_2_data_for_members['confirmed'] = case_2_data_for_members['confirmed_resumes'].apply(func)

failed = case_2_data_for_members[['uuid_vacancy', 'failed']] \
    .explode('failed') \
    .assign(label=0) \
    .rename({'failed': 'uuid_resume'}, axis=1)

confirmed = case_2_data_for_members[['uuid_vacancy', 'confirmed']] \
    .explode('confirmed') \
    .assign(label=1) \
    .rename({'confirmed': 'uuid_resume'}, axis=1)

df_train = pd.concat([failed, confirmed], sort=False, ignore_index=True)
df_train['split'] = 'train'

df_test = pd.DataFrame(
    product([vacancy_test['uuid']], resume_test['uuid']), 
    columns=['uuid_vacancy', 'uuid_resume']
)
df_test['split'] = 'test'

df_pairs = pd.concat([df_train, df_test], sort=False, ignore_index=True)

# %%
df_train.groupby('uuid_resume')['uuid_vacancy'].agg(set).apply(len).max()
# Out:
# 1

# %%
df_pairs.head()
# Out:
#                            uuid_vacancy                           uuid_resume  \
# 0  779f3a59-206a-3241-adc4-d7db504f960b  74392e00-ecfb-335b-9fc1-c2652dca06e5
# 1  779f3a59-206a-3241-adc4-d7db504f960b  2b5ad5e1-1f31-3f3f-8a66-43cd89233672
# 2  779f3a59-206a-3241-adc4-d7db504f960b  ea1ac51a-e16b-367a-9216-52fb64809db1
# 3  779f3a59-206a-3241-adc4-d7db504f960b  ecfc02a1-592c-3ed0-a801-1ad9ab3d30b8
# 4  779f3a59-206a-3241-adc4-d7db504f960b  aff6b6bd-89c2-3b2c-ab2e-0b9f76ac367c
#
#    label  split
# 0    0.0  train
# 1    0.0  train
# 2    0.0  train
# 3    0.0  train
# 4    0.0  train

# %%
# добавление валидации
np.random.seed(42)
mask = df_vacancy['title'].str.lower().str.contains('java')
val_uuid = df_vacancy[mask].sample(frac=0.3)['uuid'].tolist()
mask = df_pairs['uuid_vacancy'].isin(val_uuid)
df_pairs.loc[mask, 'split'] = 'val'

np.random.seed(42)
df_pairs = df_pairs.sample(frac=1).reset_index(drop=True)

# save
df_pairs.to_pickle(f'{DATA_PROCESSED}/df_pairs.pickle')

# %%
pd.concat([
    df_train.query('label == 1')['uuid_vacancy'].value_counts().to_frame('confirmed'),
df_train.query('label == 0')['uuid_vacancy'].value_counts().to_frame('failed'),
], axis=1)
# Out:
#                                       confirmed  failed
# a8dd83c3-178d-3c70-90c2-7c3648f6b96a         23      26
# 3c4359e8-8e2f-3c51-9b62-562080e1b549         14      59
# a8f56ed3-3ef3-365d-ade4-2df4db5d4af8         13      36
# 9d98eba0-13bb-38d3-b742-4fd445954b3d         12      11
# 01713376-e04d-3f9d-9287-7a5ff74918c3         11      11
# 259bf318-e6a7-3b6c-93f9-e1804a89ee63         10       7
# f4a7096b-e1c4-3b4c-be6a-493eb29c6b0f         10      36
# ab135980-4634-3579-8707-2f094b5579a9          9      15
# 61a5a940-c9f2-3f9f-bbda-9cf735697878          8      17
# 7a4813fc-43bc-3896-a607-4c8682b01002          8      16
# 779f3a59-206a-3241-adc4-d7db504f960b          7      11
# a5d0e1fd-7baa-3a6f-98f4-b908ac7fce43          6       5
# 47c1a3d8-84b7-3986-9214-f61679697e65          6       5
# b1148bfd-c881-3e51-92fd-29912e58b38d          6       8
# 4e2299c0-13fc-301d-8f3c-3ccfd0281ce6          4       9
# aecfdaf6-e12c-3309-8f1b-157028ef63d5          4      60
# b2315867-73a2-3d43-acac-cbb92bd793b3          4      16
# 7eca3dc1-2108-3152-85be-cd0ee7aa1493          4       8
# 042d69ba-f5fb-3248-aa7d-ae47d5ff21ea          4       5
# cdbe4d64-991a-35a1-8b71-a05a5ce24123          3      12
# 2c530588-044c-3be6-967c-a921937007be          3       6
# 72feffa1-4e1b-3745-b540-f8dd04722854          3       5
# c03085c3-9b1e-3564-bb1e-59aa72e5fbca          3      14
# 9c23bbc9-e2fe-39eb-ad49-3194275143ff          3       8
# 4c9676a3-15f9-3ec7-88ac-96dab7b343ba          3       9
# f97f9ccf-12cc-377a-8e1d-37039d591c8b          3      10
# dfaf7cc8-3726-361e-b7cf-6d9746d6bf77          3      19
# 54ec7d23-cf72-30c0-b0b5-22509ddbdfef          3      13
# 7de66249-ed0c-315d-8c52-3d9fd5082cc4          3       6
