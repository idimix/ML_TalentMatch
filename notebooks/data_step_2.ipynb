# %%
PATH = '..'
DATA_SOURCE = f'{PATH}/data/source'
DATA_PROCESSED = f'{PATH}/data/processed'

# %%
import os
import pandas as pd
import numpy as np
import polars as pl
from IPython.display import display, Markdown
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import json
from tqdm.notebook import tqdm

import torch.nn.functional as F
from torch import Tensor
from transformers import AutoTokenizer, AutoModel
from sentence_transformers import SentenceTransformer, util
import hdbscan
from umap import UMAP
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
import pymorphy2
from razdel import sentenize
import eli5
from sklearn.metrics.pairwise import cosine_similarity

from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True, nb_workers=16)
tqdm.pandas()

from sklearn.neighbors import KNeighborsClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, make_pipeline, make_union
import torch
from scipy.sparse import coo_matrix

from sklearn.preprocessing import normalize
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=UserWarning) 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# Out:
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
def plot_wordcloud(list_words):
    wordcloud = WordCloud(
        width = 2000, 
        height = 1500, 
        random_state=1, 
        background_color='black', 
        margin=20, 
        colormap='Pastel1', 
        collocations=False
    )
    frequencies = pd.Series(list_words).value_counts()
    plt.figure(figsize=(40, 30))
    plt.imshow(wordcloud.generate_from_frequencies(frequencies))
    plt.axis("off");

# %%
class Tokenizer:
    def __init__(self, pattern='[^a-zа-яё]+', norm=False, stop_words=[]):
        # pattern='[^a-zа-яё]+'
        # pattern='\W'
        self._pattern = re.compile(pattern)
        self._norm = norm
        self._morph = pymorphy2.MorphAnalyzer() if norm else None
        self._stop_words = stop_words

    def __call__(self, text):
        tokens = [token for token in self._pattern.split(text.lower()) if token != '']
        if self._norm:
            tokens = [self._morph.parse(token)[0].normal_form for token in tokens]
            
        tokens = [token for token in tokens if len(token) > 2 and token not in self._stop_words]
        return tokens

def sentenizer(text):
    text = re.sub(r"([a-zа-я\)]\s+)([А-Я])", r"\1. \2", text)
    text = re.sub(r"\s+\.", r".", text)
    text_sent = sentenize(text)
    text_sent = [sent.text for sent in text_sent]
    return text_sent

# %% [markdown]
# # Чтение данных

# %%
df_vacancy = pd.read_pickle(f'{DATA_PROCESSED}/df_vacancy.pickle')
df_resume = pd.read_pickle(f'{DATA_PROCESSED}/df_resume.pickle')
df_pairs = pd.read_pickle(f'{DATA_PROCESSED}/df_pairs.pickle')

# %% [markdown]
# # Разбивка вакансии и резюме на кластеры

# %%
titles = [
    ['ИТ-Лидер команды', 'ИТ-лидер', 'Team Lead', 'Руководитель группы разработки'],
    ['Senior Java-разработчик', 'Java разработчик senior', 'Java-разработчик проект АБС', 'Senior Java-разработчик проект брокерское обслуживание', 'Java developer', 'Java разработчик команда Инвестиции', 'Android разработчик', 'Java-разработчик', 'Java-разработчик', 'Java разработчик'],
    ['Системный аналитик', 'Системный аналитик', 'Системный аналитик финтех', 'Системный аналитик комманда Залоги'],
    ['DevOps инженер', 'DevOps'],
    ['Аналитик DWH "Hadoop"', 'Аналитик DWH', 'Ведущий/ Главный аналитик DWH', 'Архитектор/Системный аналитик DWH ДИР'],
    ['Ведущий разработчик ETL "Hadoop"', 'ETL Разработчик (ДИР)', ],
    ['Product manager', 'Product Manager'],
    ['Тестировщик'],
    ['Frontend Developer'],
    ['Python Developer'],
]
df_titles = pd.Series(titles).to_frame('title_vacancy')
df_titles['id_cluster'] = range(len(df_titles))
df_titles = df_titles.explode('title_vacancy')

clms = ['title_vacancy', 'title_resume', 'label', 'id_cluster', 'split']
df_titles = df_pairs \
    .merge(df_vacancy[['uuid', 'title']], left_on='uuid_vacancy', right_on='uuid', how='left') \
    .merge(df_resume[['uuid', 'title']], left_on='uuid_resume', right_on='uuid', suffixes=['_vacancy', '_resume'], how='left') \
    .merge(df_titles, on='title_vacancy', how='left')[clms]
# Out:
# /tmp/ipykernel_1264180/2188640619.py:18: FutureWarning: Passing 'suffixes' which cause duplicate columns {'uuid_vacancy'} in the result is deprecated and will raise a MergeError in a future version.
#   df_titles = df_pairs \

# %%
df_titles.isna().sum()
# Out:
# title_vacancy      0
# title_resume       0
# label            113
# id_cluster         0
# split              0
# dtype: int64

# %%
df_titles.query('title_resume == ""')
# Out:
# Empty DataFrame
# Columns: [title_vacancy, title_resume, label, id_cluster, split]
# Index: []

# %%
cluster_names = [
    'Team Lead',
    'Java-разработчик',
    'Системный аналитик',
    'DevOps',
    'Аналитик DWH',
    'ETL Разработчик',
    'Product Manager',
    'Тестировщик',
    'Frontend Developer',
    'Python Developer',
]
cluster2title = pd.Series(dict(enumerate(cluster_names)))

title2cluster = pd.concat([
    df_titles.set_index('title_vacancy')['id_cluster'],
    df_titles.set_index('title_resume')['id_cluster']
])
title2cluster = pd.Series(title2cluster.to_dict())

# %%
print(*cluster_names, sep='\n')
# Out:
# Team Lead
# Java-разработчик
# Системный аналитик
# DevOps
# Аналитик DWH
# ETL Разработчик
# Product Manager
# Тестировщик
# Frontend Developer
# Python Developer

# %%
for id_cluster, subset in df_titles.query('label == 1').groupby('id_cluster'):
    display(subset)
    print()
# Out:
#                       title_vacancy                        title_resume  \
# 162  Руководитель группы разработки                      Team Lead Java
# 215  Руководитель группы разработки                           Team Lead
# 236                ИТ-Лидер команды                           Team Lead
# 287                        ИТ-лидер                           Team Lead
# 296                ИТ-Лидер команды            Ведущий Java-разработчик
# 469  Руководитель группы разработки                           Team Lead
# 493                        ИТ-лидер                           Team Lead
# 589  Руководитель группы разработки                                Lead
# 645                        ИТ-лидер                           Tech lead
# 652                ИТ-Лидер команды                                Lead
# 694  Руководитель группы разработки                           Team Lead
# 716  Руководитель группы разработки                           Lead Java
# 752                ИТ-Лидер команды  Ведущий Java разработчик/Tech Lead
# 838                ИТ-Лидер команды                   Тимлид/архитектор
# 850                ИТ-Лидер команды                           Team Lead
# 868                ИТ-Лидер команды                           Team Lead
# 880                ИТ-Лидер команды     Технический руководитель стрима
#
#      label  id_cluster  split
# 162    1.0           0  train
# 215    1.0           0  train
# 236    1.0           0  train
# 287    1.0           0  train
# 296    1.0           0  train
# 469    1.0           0  train
# 493    1.0           0  train
# 589    1.0           0  train
# 645    1.0           0  train
# 652    1.0           0  train
# 694    1.0           0  train
# 716    1.0           0  train
# 752    1.0           0  train
# 838    1.0           0  train
# 850    1.0           0  train
# 868    1.0           0  train
# 880    1.0           0  train
#                                          title_vacancy  \
# 2                          Java-разработчик проект АБС
# 20                             Java разработчик senior
# 22                                    Java-разработчик
# 23                                    Java-разработчик
# 30                                    Java-разработчик
# 31                                    Java-разработчик
# 51                                    Java-разработчик
# 52                                    Java-разработчик
# 60   Senior Java-разработчик проект брокерское обсл...
# 61                                      Java developer
# 75                                      Java developer
# 113                Java разработчик команда Инвестиции
# 129                        Java-разработчик проект АБС
# 142                            Java разработчик senior
# 166                            Java разработчик senior
# 167                        Java-разработчик проект АБС
# 181                            Senior Java-разработчик
# 187                        Java-разработчик проект АБС
# 192                            Senior Java-разработчик
# 208                                   Java-разработчик
# 209                                   Java-разработчик
# 226                        Java-разработчик проект АБС
# 237  Senior Java-разработчик проект брокерское обсл...
# 243                                   Java-разработчик
# 244                                   Java-разработчик
# 257                Java разработчик команда Инвестиции
# 271                        Java-разработчик проект АБС
# 295                            Java разработчик senior
# 303                Java разработчик команда Инвестиции
# 322                                   Java-разработчик
# 323                                   Java-разработчик
# 349                                     Java developer
# 354                        Java-разработчик проект АБС
# 382                                   Java-разработчик
# 383                                   Java-разработчик
# 393                        Java-разработчик проект АБС
# 419                            Java разработчик senior
# 424                            Senior Java-разработчик
# 430                            Java разработчик senior
# 518                                Android разработчик
# 521                                   Java-разработчик
# 522                                   Java-разработчик
# 543                                     Java developer
# 544                        Java-разработчик проект АБС
# 549                Java разработчик команда Инвестиции
# 555  Senior Java-разработчик проект брокерское обсл...
# 574                        Java-разработчик проект АБС
# 602                Java разработчик команда Инвестиции
# 617                                   Java-разработчик
# 618                                   Java-разработчик
# 625                                Android разработчик
# 643                            Java разработчик senior
# 659                        Java-разработчик проект АБС
# 670                Java разработчик команда Инвестиции
# 695                            Java разработчик senior
# 701                            Java разработчик senior
# 728  Senior Java-разработчик проект брокерское обсл...
# 736                        Java-разработчик проект АБС
# 766                                   Java-разработчик
# 767                                   Java-разработчик
# 769                        Java-разработчик проект АБС
# 793                                Android разработчик
# 856                            Java разработчик senior
# 905                Java разработчик команда Инвестиции
# 907                        Java-разработчик проект АБС
#
#                                        title_resume  label  id_cluster  split
# 2    Главный специалист поддержки банковских систем    1.0           1  train
# 20                                   Java developer    1.0           1  train
# 22                                 Java Разработчик    1.0           1  train
# 23                                 Java Разработчик    1.0           1  train
# 30                    Ведущий инженер по разработке    1.0           1    val
# 31                    Ведущий инженер по разработке    1.0           1    val
# 51                          Java/Kotlin разработчик    1.0           1  train
# 52                          Java/Kotlin разработчик    1.0           1  train
# 60                                   Java Developer    1.0           1    val
# 61                         Старший Java разработчик    1.0           1    val
# 75                                   Java Developer    1.0           1    val
# 113                 Главный инженер Java-разработки    1.0           1  train
# 129                             Ведущий разработчик    1.0           1  train
# 142                          Java Software Engineer    1.0           1  train
# 166                     Ведущий эксперт-разработчик    1.0           1  train
# 167                         Программист-разработчик    1.0           1  train
# 181                             Ведущий разработчик    1.0           1  train
# 187                                  Java Developer    1.0           1  train
# 192                               Backend Developer    1.0           1  train
# 208                           Senior Java Developer    1.0           1    val
# 209                           Senior Java Developer    1.0           1    val
# 226                                  Java developer    1.0           1  train
# 237                                Java-разработчик    1.0           1    val
# 243                           Tech lead разработчик    1.0           1  train
# 244                           Tech lead разработчик    1.0           1  train
# 257                                Java-разработчик    1.0           1  train
# 271                                  Java Developer    1.0           1  train
# 295                                  Java developer    1.0           1  train
# 303                          Software Java engineer    1.0           1  train
# 322                                  Java Developer    1.0           1    val
# 323                                  Java Developer    1.0           1    val
# 349                                  Java developer    1.0           1    val
# 354                           Senior Java Developer    1.0           1  train
# 382                                Java разработчик    1.0           1    val
# 383                                Java разработчик    1.0           1    val
# 393                           Tech lead разработчик    1.0           1  train
# 419                        Senior Software Engineer    1.0           1  train
# 424                               Software Engineer    1.0           1  train
# 430                                  Java developer    1.0           1  train
# 518                             Android разработчик    1.0           1  train
# 521                   Главный инженер по разработке    1.0           1  train
# 522                   Главный инженер по разработке    1.0           1  train
# 543                     ведущий инженер-разработчик    1.0           1    val
# 544                           Senior Java Developer    1.0           1  train
# 549                                        Teamlead    1.0           1  train
# 555              Ведущий Java-разработчик/Tech Lead    1.0           1    val
# 574                             Ведущий разработчик    1.0           1  train
# 602                             Старший разработчик    1.0           1  train
# 617                                  Java Developer    1.0           1    val
# 618                                  Java Developer    1.0           1    val
# 625                             Android разработчик    1.0           1  train
# 643                      Старший бекенд-разработчик    1.0           1  train
# 659                                Java-разработчик    1.0           1  train
# 670                                java-разработчик    1.0           1  train
# 695                                Java-разработчик    1.0           1  train
# 701                           Senior Java Developer    1.0           1  train
# 728                        Технический руководитель    1.0           1    val
# 736                Главный Java разработчик проекта    1.0           1  train
# 766                           Senior Java Developer    1.0           1    val
# 767                           Senior Java Developer    1.0           1    val
# 769                        Старший Java-разработчик    1.0           1  train
# 793                               Android Developer    1.0           1  train
# 856                          Java Backend Developer    1.0           1  train
# 905                                       Наставник    1.0           1  train
# 907                                Java-разработчик    1.0           1  train
#                           title_vacancy  \
# 4                    Системный аналитик
# 5                    Системный аналитик
# 17                   Системный аналитик
# 18                   Системный аналитик
# 24            Системный аналитик финтех
# 47                   Системный аналитик
# 48                   Системный аналитик
# 58                   Системный аналитик
# 59                   Системный аналитик
# 68                   Системный аналитик
# 69                   Системный аналитик
# 77                   Системный аналитик
# 78                   Системный аналитик
# 95   Системный аналитик комманда Залоги
# 116                  Системный аналитик
# 117                  Системный аналитик
# 119                  Системный аналитик
# 120                  Системный аналитик
# 123           Системный аналитик финтех
# 157           Системный аналитик финтех
# 172                  Системный аналитик
# 173                  Системный аналитик
# 230                  Системный аналитик
# 231                  Системный аналитик
# 246                  Системный аналитик
# 247                  Системный аналитик
# 254  Системный аналитик комманда Залоги
# 278                  Системный аналитик
# 279                  Системный аналитик
# 280           Системный аналитик финтех
# 314  Системный аналитик комманда Залоги
# 332                  Системный аналитик
# 333                  Системный аналитик
# 351  Системный аналитик комманда Залоги
# 377  Системный аналитик комманда Залоги
# 385                  Системный аналитик
# 386                  Системный аналитик
# 390  Системный аналитик комманда Залоги
# 422           Системный аналитик финтех
# 427  Системный аналитик комманда Залоги
# 473                  Системный аналитик
# 474                  Системный аналитик
# 487                  Системный аналитик
# 488                  Системный аналитик
# 516  Системный аналитик комманда Залоги
# 535  Системный аналитик комманда Залоги
# 540  Системный аналитик комманда Залоги
# 558  Системный аналитик комманда Залоги
# 563                  Системный аналитик
# 564                  Системный аналитик
# 575           Системный аналитик финтех
# 577           Системный аналитик финтех
# 614                  Системный аналитик
# 615                  Системный аналитик
# 628           Системный аналитик финтех
# 661           Системный аналитик финтех
# 662                  Системный аналитик
# 663                  Системный аналитик
# 709                  Системный аналитик
# 710                  Системный аналитик
# 729                  Системный аналитик
# 730                  Системный аналитик
# 744  Системный аналитик комманда Залоги
# 746           Системный аналитик финтех
# 770           Системный аналитик финтех
# 775                  Системный аналитик
# 776                  Системный аналитик
# 785                  Системный аналитик
# 786                  Системный аналитик
# 794                  Системный аналитик
# 795                  Системный аналитик
# 799                  Системный аналитик
# 800                  Системный аналитик
# 804  Системный аналитик комманда Залоги
# 811                  Системный аналитик
# 812                  Системный аналитик
# 831                  Системный аналитик
# 832                  Системный аналитик
# 862                  Системный аналитик
# 863                  Системный аналитик
# 872                  Системный аналитик
# 873                  Системный аналитик
# 878                  Системный аналитик
# 879                  Системный аналитик
# 892                  Системный аналитик
# 893                  Системный аналитик
#
#                                           title_resume  label  id_cluster  \
# 4                                   Системный аналитик    1.0           2
# 5                                   Системный аналитик    1.0           2
# 17                                  Системный аналитик    1.0           2
# 18                                  Системный аналитик    1.0           2
# 24                          Ведущий системный аналитик    1.0           2
# 47                                  Системный аналитик    1.0           2
# 48                                  Системный аналитик    1.0           2
# 58                          Ведущий системный аналитик    1.0           2
# 59                          Ведущий системный аналитик    1.0           2
# 68                                  Системный аналитик    1.0           2
# 69                                  Системный аналитик    1.0           2
# 77                                            Аналитик    1.0           2
# 78                                            Аналитик    1.0           2
# 95                          Ведущий системный аналитик    1.0           2
# 116                              Senior System Analyst    1.0           2
# 117                              Senior System Analyst    1.0           2
# 119                 Системный аналитик/Бизнес аналитик    1.0           2
# 120                 Системный аналитик/Бизнес аналитик    1.0           2
# 123                        Системный аналитик (middle)    1.0           2
# 157                           Руководитель направления    1.0           2
# 172                                 Системный аналитик    1.0           2
# 173                                 Системный аналитик    1.0           2
# 230                                 Системный аналитик    1.0           2
# 231                                 Системный аналитик    1.0           2
# 246                         Ведущий системный аналитик    1.0           2
# 247                         Ведущий системный аналитик    1.0           2
# 254                                 Системный аналитик    1.0           2
# 278                   Senior system & business analyst    1.0           2
# 279                   Senior system & business analyst    1.0           2
# 280                                     System Analyst    1.0           2
# 314                        Бизнес / Системный аналитик    1.0           2
# 332                                   Главный аналитик    1.0           2
# 333                                   Главный аналитик    1.0           2
# 351                         Ведущий системный аналитик    1.0           2
# 377            Ведущий системный аналитик / Архитектор    1.0           2
# 385                                 Системный аналитик    1.0           2
# 386                                 Системный аналитик    1.0           2
# 390                                 Системный аналитик    1.0           2
# 422                          Системный бизнес аналитик    1.0           2
# 427                                   Ведущий аналитик    1.0           2
# 473       Старший бизнес-аналитик (системный аналитик)    1.0           2
# 474       Старший бизнес-аналитик (системный аналитик)    1.0           2
# 487                          Бизнес\системный аналитик    1.0           2
# 488                          Бизнес\системный аналитик    1.0           2
# 516  Ведущий системный аналитик/Руководитель/Систем...    1.0           2
# 535                         Старший системный аналитик    1.0           2
# 540                                 Системный-аналитик    1.0           2
# 558                                 Системный аналитик    1.0           2
# 563  Главный инженер по разработке/ Системный Аналитик    1.0           2
# 564  Главный инженер по разработке/ Системный Аналитик    1.0           2
# 575                         Старший системный аналитик    1.0           2
# 577                                 Системный аналитик    1.0           2
# 614                         Ведущий системный аналитик    1.0           2
# 615                         Ведущий системный аналитик    1.0           2
# 628                            Старший бизнес-аналитик    1.0           2
# 661                         Старший системный аналитик    1.0           2
# 662                                   Ведущий Аналитик    1.0           2
# 663                                   Ведущий Аналитик    1.0           2
# 709                              Руководитель проектов    1.0           2
# 710                              Руководитель проектов    1.0           2
# 729                 Systems Analyst / Business Analyst    1.0           2
# 730                 Systems Analyst / Business Analyst    1.0           2
# 744                                 Системный аналитик    1.0           2
# 746                                   Инженер-аналитик    1.0           2
# 770          Системный аналитик, проектировщик системы    1.0           2
# 775                          Системный\бизнес аналитик    1.0           2
# 776                          Системный\бизнес аналитик    1.0           2
# 785                                 Системный аналитик    1.0           2
# 786                                 Системный аналитик    1.0           2
# 794                         Ведущий системный аналитик    1.0           2
# 795                         Ведущий системный аналитик    1.0           2
# 799  Руководитель направления, тех. лид, ведущий си...    1.0           2
# 800  Руководитель направления, тех. лид, ведущий си...    1.0           2
# 804                         Ведущий системный аналитик    1.0           2
# 811       Senior Information Technology System Analyst    1.0           2
# 812       Senior Information Technology System Analyst    1.0           2
# 831                                 Системный аналитик    1.0           2
# 832                                 Системный аналитик    1.0           2
# 862                                   Старший аналитик    1.0           2
# 863                                   Старший аналитик    1.0           2
# 872                                 Системный-аналитик    1.0           2
# 873                                 Системный-аналитик    1.0           2
# 878  Ведущий системный аналитик/Руководитель/Систем...    1.0           2
# 879  Ведущий системный аналитик/Руководитель/Систем...    1.0           2
# 892                              Senior System Analyst    1.0           2
# 893                              Senior System Analyst    1.0           2
#
#      split
# 4    train
# 5    train
# 17   train
# 18   train
# 24   train
# 47   train
# 48   train
# 58   train
# 59   train
# 68   train
# 69   train
# 77   train
# 78   train
# 95   train
# 116  train
# 117  train
# 119  train
# 120  train
# 123  train
# 157  train
# 172  train
# 173  train
# 230  train
# 231  train
# 246  train
# 247  train
# 254  train
# 278  train
# 279  train
# 280  train
# 314  train
# 332  train
# 333  train
# 351  train
# 377  train
# 385  train
# 386  train
# 390  train
# 422  train
# 427  train
# 473  train
# 474  train
# 487  train
# 488  train
# 516  train
# 535  train
# 540  train
# 558  train
# 563  train
# 564  train
# 575  train
# 577  train
# 614  train
# 615  train
# 628  train
# 661  train
# 662  train
# 663  train
# 709  train
# 710  train
# 729  train
# 730  train
# 744  train
# 746  train
# 770  train
# 775  train
# 776  train
# 785  train
# 786  train
# 794  train
# 795  train
# 799  train
# 800  train
# 804  train
# 811  train
# 812  train
# 831  train
# 832  train
# 862  train
# 863  train
# 872  train
# 873  train
# 878  train
# 879  train
# 892  train
# 893  train
#       title_vacancy                          title_resume  label  id_cluster  \
# 9            DevOps                                DevOps    1.0           3
# 253          DevOps                        DevOps инженер    1.0           3
# 273  DevOps инженер                                DevOps    1.0           3
# 308          DevOps                       DevOps Engineer    1.0           3
# 352  DevOps инженер  DevOps инженер\Главный инженер CI/CD    1.0           3
# 478          DevOps                       DevOps Engineer    1.0           3
# 507          DevOps                                DevOps    1.0           3
# 554          DevOps                       DevOps engineer    1.0           3
# 556  DevOps инженер                        DevOps-инженер    1.0           3
# 610          DevOps                                DevOps    1.0           3
# 623  DevOps инженер                       DevOps engineer    1.0           3
# 754          DevOps                       DevOps Engineer    1.0           3
# 772          DevOps                                DevOps    1.0           3
#
#      split
# 9    train
# 253  train
# 273  train
# 308  train
# 352  train
# 478  train
# 507  train
# 554  train
# 556  train
# 610  train
# 623  train
# 754  train
# 772  train
#                              title_vacancy  \
# 42   Архитектор/Системный аналитик DWH ДИР
# 224                           Аналитик DWH
# 283                           Аналитик DWH
# 359          Ведущий/ Главный аналитик DWH
# 429          Ведущий/ Главный аналитик DWH
# 443                           Аналитик DWH
# 451  Архитектор/Системный аналитик DWH ДИР
# 578          Ведущий/ Главный аналитик DWH
# 666                  Аналитик DWH "Hadoop"
# 668  Архитектор/Системный аналитик DWH ДИР
# 740  Архитектор/Системный аналитик DWH ДИР
# 834                  Аналитик DWH "Hadoop"
# 867                  Аналитик DWH "Hadoop"
#
#                                   title_resume  label  id_cluster  split
# 42                                Аналитик DWH    1.0           4  train
# 224                   Аналитик хранилищ данных    1.0           4  train
# 283                              Analyst (DWH)    1.0           4  train
# 359                     системный аналитик DWH    1.0           4  train
# 429  Ведущий инженер разработки / Аналитик DWH    1.0           4  train
# 443                                DWH Analyst    1.0           4  train
# 451                     Системный аналитик DWH    1.0           4  train
# 578                               Аналитик DWH    1.0           4  train
# 666                               Аналитик DWH    1.0           4  train
# 668                                Dwh analyst    1.0           4  train
# 740          Системный аналитик/Архитектор DWH    1.0           4  train
# 834                               Аналитик DWH    1.0           4  train
# 867    Системный аналитик DWH + BI разработчик    1.0           4  train
#                         title_vacancy                            title_resume  \
# 29              ETL Разработчик (ДИР)             Ведущий инженер-программист
# 45              ETL Разработчик (ДИР)                         ETL-разработчик
# 216             ETL Разработчик (ДИР)  Руководитель направления Data Engineer
# 301             ETL Разработчик (ДИР)                           Data engineer
# 565             ETL Разработчик (ДИР)                 Ведущий ETL-разработчик
# 621  Ведущий разработчик ETL "Hadoop"                   Инженер по разработке
# 624  Ведущий разработчик ETL "Hadoop"                         Главный инженер
# 651             ETL Разработчик (ДИР)                           Data Engineer
# 756  Ведущий разработчик ETL "Hadoop"                           ETL Developer
#
#      label  id_cluster  split
# 29     1.0           5  train
# 45     1.0           5  train
# 216    1.0           5  train
# 301    1.0           5  train
# 565    1.0           5  train
# 621    1.0           5  train
# 624    1.0           5  train
# 651    1.0           5  train
# 756    1.0           5  train
#        title_vacancy                                  title_resume  label  \
# 65   Product manager  Product Lead направления "Карьерные сервисы"    1.0
# 88   Product manager              IT & Product Operations Director    1.0
# 90   Product Manager                      Product Lead of Payments    1.0
# 145  Product manager                                  Product Lead    1.0
# 233  Product manager                                           CPO    1.0
# 336  Product manager                   Product manager | Part-time    1.0
# 366  Product Manager                         Директор по Продуктам    1.0
# 510  Product manager                                 Product Owner    1.0
# 585  Product manager                          Lead Product Manager    1.0
# 699  Product Manager                               Product manager    1.0
# 704  Product manager                               Head of Product    1.0
# 732  Product manager                           CIS Product manager    1.0
# 842  Product manager   Директор департамента продуктов и инноваций    1.0
# 865  Product manager                               Product manager    1.0
# 875  Product manager              Unit Lead направления Интеграций    1.0
#
#      id_cluster  split
# 65            6  train
# 88            6  train
# 90            6  train
# 145           6  train
# 233           6  train
# 336           6  train
# 366           6  train
# 510           6  train
# 585           6  train
# 699           6  train
# 704           6  train
# 732           6  train
# 842           6  train
# 865           6  train
# 875           6  train
#     title_vacancy                title_resume  label  id_cluster  split
# 222   Тестировщик         инженер-тестировщик    1.0           7  train
# 739   Тестировщик  Инженер по тестированию ПО    1.0           7  train
# 828   Тестировщик     Инженер по тестированию    1.0           7  train
#           title_vacancy                        title_resume  label  \
# 161  Frontend Developer        Ведущий Frontend разработчик    1.0
# 309  Frontend Developer  Senior/TechLead Frontend Developer    1.0
# 406  Frontend Developer                Frontend-разработчик    1.0
# 434  Frontend Developer                  Frontend Developer    1.0
# 642  Frontend Developer         Старший fronend-разработчик    1.0
# 738  Frontend Developer                Frontend-разработчик    1.0
# 749  Frontend Developer          Senior Fullstack Developer    1.0
# 763  Frontend Developer                Frontend разработчик    1.0
# 801  Frontend Developer           Senior Frontend Developer    1.0
# 861  Frontend Developer           Senior Frontend Developer    1.0
#
#      id_cluster  split
# 161           8  train
# 309           8  train
# 406           8  train
# 434           8  train
# 642           8  train
# 738           8  train
# 749           8  train
# 763           8  train
# 801           8  train
# 861           8  train
#         title_vacancy        title_resume  label  id_cluster  split
# 291  Python Developer    Python developer    1.0           9  train
# 409  Python Developer      Lead developer    1.0           9  train
# 706  Python Developer  Python разработчик    1.0           9  train

# %%
for id_cluster, subset in df_titles.query('label == 0').groupby('id_cluster'):
    display(subset)
    print()
# Out:
#                       title_vacancy  \
# 13                 ИТ-Лидер команды
# 36                         ИТ-лидер
# 67                         ИТ-лидер
# 91                         ИТ-лидер
# 97                 ИТ-Лидер команды
# 147                ИТ-Лидер команды
# 156                ИТ-Лидер команды
# 183  Руководитель группы разработки
# 189  Руководитель группы разработки
# 227                        ИТ-лидер
# 272                ИТ-Лидер команды
# 362                        ИТ-лидер
# 402                ИТ-Лидер команды
# 445                ИТ-Лидер команды
# 530                        ИТ-лидер
# 546                ИТ-Лидер команды
# 595                        ИТ-лидер
# 611                ИТ-Лидер команды
# 655  Руководитель группы разработки
# 672                ИТ-Лидер команды
# 677                ИТ-Лидер команды
# 679  Руководитель группы разработки
# 684                ИТ-Лидер команды
# 721                        ИТ-лидер
# 780                ИТ-Лидер команды
# 814                ИТ-Лидер команды
# 819  Руководитель группы разработки
# 826                ИТ-Лидер команды
# 870                ИТ-Лидер команды
# 888                ИТ-Лидер команды
#
#                                           title_resume  label  id_cluster  \
# 13                                           Java lead    0.0           0
# 36                                      Team Lead Java    0.0           0
# 67                                     TeamLead - Java    0.0           0
# 91                                           Team Lead    0.0           0
# 97                     Senior Developer/Java Team Lead    0.0           0
# 147                                     Java Team Lead    0.0           0
# 156                                  Владелец продукта    0.0           0
# 183                                          Team Lead    0.0           0
# 189                                          Tech Lead    0.0           0
# 227           Senior Java Software Engineer\ Team Lead    0.0           0
# 272                                    Senior/TeamLead    0.0           0
# 362                                          Team Lead    0.0           0
# 402                                          Lead Java    0.0           0
# 445                                    TeamLead - Java    0.0           0
# 530                                          Lead Java    0.0           0
# 546                             Lead Software Engineer    0.0           0
# 595                                          Team Lead    0.0           0
# 611                                                NDA    0.0           0
# 655             Senior Java/Kotlin Developer/Tech Lead    0.0           0
# 672  Tech lead java (Руководитель направления Java ...    0.0           0
# 677                                          Team Lead    0.0           0
# 679                                          Team Lead    0.0           0
# 684                                Ведущий программист    0.0           0
# 721                                          Team Lead    0.0           0
# 780                                          Team Lead    0.0           0
# 814                                          Team Lead    0.0           0
# 819                                          Team Lead    0.0           0
# 826                                 Ведущий инженер ПО    0.0           0
# 870              Senior java developer/Team leader R&D    0.0           0
# 888                         Техлид/ведущий разработчик    0.0           0
#
#      split
# 13   train
# 36   train
# 67   train
# 91   train
# 97   train
# 147  train
# 156  train
# 183  train
# 189  train
# 227  train
# 272  train
# 362  train
# 402  train
# 445  train
# 530  train
# 546  train
# 595  train
# 611  train
# 655  train
# 672  train
# 677  train
# 679  train
# 684  train
# 721  train
# 780  train
# 814  train
# 819  train
# 826  train
# 870  train
# 888  train
#                                          title_vacancy      title_resume  \
# 1                          Java-разработчик проект АБС  Java разработчик
# 8                          Java-разработчик проект АБС  Java-разработчик
# 14                             Java разработчик senior  Java разработчик
# 16                         Java-разработчик проект АБС    Java Developer
# 25                                      Java developer    Java Developer
# ..                                                 ...               ...
# 900  Senior Java-разработчик проект брокерское обсл...    Java Developer
# 903                        Java-разработчик проект АБС  Java-разработчик
# 913                            Java разработчик senior    Java developer
# 914                                   Java-разработчик  Java-разработчик
# 915                                   Java-разработчик  Java-разработчик
#
#      label  id_cluster  split
# 1      0.0           1  train
# 8      0.0           1  train
# 14     0.0           1  train
# 16     0.0           1  train
# 25     0.0           1    val
# ..     ...         ...    ...
# 900    0.0           1    val
# 903    0.0           1  train
# 913    0.0           1  train
# 914    0.0           1  train
# 915    0.0           1  train
#
# [279 rows x 5 columns]
#                           title_vacancy                title_resume  label  \
# 7    Системный аналитик комманда Залоги            Ведущий Аналитик    0.0
# 10            Системный аналитик финтех                    Аналитик    0.0
# 35   Системный аналитик комманда Залоги          Системный аналитик    0.0
# 43                   Системный аналитик  Ведущий системный аналитик    0.0
# 44                   Системный аналитик  Ведущий системный аналитик    0.0
# ..                                  ...                         ...    ...
# 906  Системный аналитик комманда Залоги          Системный аналитик    0.0
# 908                  Системный аналитик            Ведущий аналитик    0.0
# 909                  Системный аналитик            Ведущий аналитик    0.0
# 912  Системный аналитик комманда Залоги  Ведущий системный аналитик    0.0
# 916  Системный аналитик комманда Залоги          Системный аналитик    0.0
#
#      id_cluster  split
# 7             2  train
# 10            2  train
# 35            2  train
# 43            2  train
# 44            2  train
# ..          ...    ...
# 906           2  train
# 908           2  train
# 909           2  train
# 912           2  train
# 916           2  train
#
# [131 rows x 5 columns]
#       title_vacancy                           title_resume  label  id_cluster  \
# 12           DevOps            Главный специалист (DevOps)    0.0           3
# 21           DevOps                  DevOps, web developer    0.0           3
# 110  DevOps инженер                                 DevOps    0.0           3
# 121          DevOps                         DevOps инженер    0.0           3
# 159          DevOps                             Инженер L2    0.0           3
# 176          DevOps                        DevOps Engineer    0.0           3
# 210  DevOps инженер                        DevOps Engineer    0.0           3
# 219  DevOps инженер                         DevOps инженер    0.0           3
# 277  DevOps инженер                        DevOps Engineer    0.0           3
# 284  DevOps инженер                 Главный DevOps инженер    0.0           3
# 304          DevOps                       Tech Lead DevOps    0.0           3
# 376          DevOps                         DevOps инженер    0.0           3
# 482  DevOps инженер                      Cпециалист DevOps    0.0           3
# 484  DevOps инженер                         DevOps-инженер    0.0           3
# 536          DevOps                                 DevOps    0.0           3
# 586          DevOps                        TeamLead DevOps    0.0           3
# 627          DevOps                                 DevOps    0.0           3
# 697          DevOps                                 DevOps    0.0           3
# 726          DevOps                  Инженер автоматизации    0.0           3
# 764          DevOps                         Ведущий DevOps    0.0           3
# 796  DevOps инженер                        Devops Engineer    0.0           3
# 815          DevOps  Senior Infastructure Support Engineer    0.0           3
# 904          DevOps                         DevOps инженер    0.0           3
#
#      split
# 12   train
# 21   train
# 110  train
# 121  train
# 159  train
# 176  train
# 210  train
# 219  train
# 277  train
# 284  train
# 304  train
# 376  train
# 482  train
# 484  train
# 536  train
# 586  train
# 627  train
# 697  train
# 726  train
# 764  train
# 796  train
# 815  train
# 904  train
#                              title_vacancy  \
# 6                    Аналитик DWH "Hadoop"
# 26                   Аналитик DWH "Hadoop"
# 28                   Аналитик DWH "Hadoop"
# 50           Ведущий/ Главный аналитик DWH
# 53           Ведущий/ Главный аналитик DWH
# 54           Ведущий/ Главный аналитик DWH
# 55           Ведущий/ Главный аналитик DWH
# 76                            Аналитик DWH
# 79                   Аналитик DWH "Hadoop"
# 80                   Аналитик DWH "Hadoop"
# 143  Архитектор/Системный аналитик DWH ДИР
# 190  Архитектор/Системный аналитик DWH ДИР
# 214          Ведущий/ Главный аналитик DWH
# 293          Ведущий/ Главный аналитик DWH
# 360                           Аналитик DWH
# 384                  Аналитик DWH "Hadoop"
# 421  Архитектор/Системный аналитик DWH ДИР
# 509          Ведущий/ Главный аналитик DWH
# 542                           Аналитик DWH
# 596  Архитектор/Системный аналитик DWH ДИР
# 597          Ведущий/ Главный аналитик DWH
# 641                  Аналитик DWH "Hadoop"
# 646          Ведущий/ Главный аналитик DWH
# 649                           Аналитик DWH
# 745          Ведущий/ Главный аналитик DWH
# 758                  Аналитик DWH "Hadoop"
# 779          Ведущий/ Главный аналитик DWH
# 782          Ведущий/ Главный аналитик DWH
# 784  Архитектор/Системный аналитик DWH ДИР
# 810          Ведущий/ Главный аналитик DWH
# 820                           Аналитик DWH
# 840                  Аналитик DWH "Hadoop"
# 841          Ведущий/ Главный аналитик DWH
# 881                           Аналитик DWH
#
#                                           title_resume  label  id_cluster  \
# 6                               Системный аналитик DWH    0.0           4
# 26                              Системный аналитик DWH    0.0           4
# 28                          Data engineer/Аналитик DWH    0.0           4
# 50                                     Аналитик данных    0.0           4
# 53                                Ведущий аналитик DWH    0.0           4
# 54                                            Аналитик    0.0           4
# 55        Ведущий программист (SQL, DWH)/ Аналитик DWH    0.0           4
# 76                                  Senior DWH Analyst    0.0           4
# 79                                  Системный аналитик    0.0           4
# 80                                        Аналитик DWH    0.0           4
# 143                            Data Engineer Tech Lead    0.0           4
# 190                        Ведущий инженер-программист    0.0           4
# 214                         Руководитель DWH аналитики    0.0           4
# 293                      Аналитик данных/data engineer    0.0           4
# 360                                       Аналитик DWH    0.0           4
# 384                               Главный аналитик DWH    0.0           4
# 421                                    Аналитик DWH/BI    0.0           4
# 509                 Аналитик DWH (отдел сопровождения)    0.0           4
# 542                               Главный аналитик DWH    0.0           4
# 596                     Старший системный аналитик DWH    0.0           4
# 597                                           Аналитик    0.0           4
# 641                                           Аналитик    0.0           4
# 646                             Системный аналитик DWH    0.0           4
# 649                                           Аналитик    0.0           4
# 745                             Системный аналитик DWH    0.0           4
# 758                             Системный аналитик DWH    0.0           4
# 779                                           аналитик    0.0           4
# 782  Руководитель направления методологии и моделир...    0.0           4
# 784                                 Системный аналитик    0.0           4
# 810                                       Аналитик DWH    0.0           4
# 820                                       Аналитик DWH    0.0           4
# 840                           Аналитик хранилищ данных    0.0           4
# 841                                    Аналитик данных    0.0           4
# 881                               Аналитик-разработчик    0.0           4
#
#      split
# 6    train
# 26   train
# 28   train
# 50   train
# 53   train
# 54   train
# 55   train
# 76   train
# 79   train
# 80   train
# 143  train
# 190  train
# 214  train
# 293  train
# 360  train
# 384  train
# 421  train
# 509  train
# 542  train
# 596  train
# 597  train
# 641  train
# 646  train
# 649  train
# 745  train
# 758  train
# 779  train
# 782  train
# 784  train
# 810  train
# 820  train
# 840  train
# 841  train
# 881  train
#                         title_vacancy             title_resume  label  \
# 66              ETL Разработчик (ДИР)            data engineer    0.0
# 82              ETL Разработчик (ДИР)          ETL разработчик    0.0
# 105  Ведущий разработчик ETL "Hadoop"            Data Engineer    0.0
# 197             ETL Разработчик (ДИР)  Старший разработчик ETL    0.0
# 198  Ведущий разработчик ETL "Hadoop"      ETL / Data Engineer    0.0
# 212  Ведущий разработчик ETL "Hadoop"            Code reviewer    0.0
# 213  Ведущий разработчик ETL "Hadoop"            Data engineer    0.0
# 316  Ведущий разработчик ETL "Hadoop"     Ведущий дата инженер    0.0
# 404             ETL Разработчик (ДИР)            Data engineer    0.0
# 411             ETL Разработчик (ДИР)            Data engineer    0.0
# 519  Ведущий разработчик ETL "Hadoop"            Data Engineer    0.0
# 598  Ведущий разработчик ETL "Hadoop"          ETL Разработчик    0.0
# 599             ETL Разработчик (ДИР)        DWH/Data Engineer    0.0
# 620  Ведущий разработчик ETL "Hadoop"            Data Engineer    0.0
# 712             ETL Разработчик (ДИР)           Инженер данных    0.0
# 715             ETL Разработчик (ДИР)          Главный инженер    0.0
# 743  Ведущий разработчик ETL "Hadoop"          ETL разработчик    0.0
# 809  Ведущий разработчик ETL "Hadoop"          ETL-разработчик    0.0
# 827  Ведущий разработчик ETL "Hadoop"             Дата-Инженер    0.0
# 859  Ведущий разработчик ETL "Hadoop"             Дата инженер    0.0
# 886  Ведущий разработчик ETL "Hadoop"   Старший инженер данных    0.0
#
#      id_cluster  split
# 66            5  train
# 82            5  train
# 105           5  train
# 197           5  train
# 198           5  train
# 212           5  train
# 213           5  train
# 316           5  train
# 404           5  train
# 411           5  train
# 519           5  train
# 598           5  train
# 599           5  train
# 620           5  train
# 712           5  train
# 715           5  train
# 743           5  train
# 809           5  train
# 827           5  train
# 859           5  train
# 886           5  train
#        title_vacancy                                       title_resume  \
# 40   Product manager                              Product manager сайта
# 56   Product manager  Head of Product / Руководитель продуктового на...
# 122  Product manager                                  Менеджер продукта
# 125  Product manager                                   Продакт-менеджер
# 126  Product Manager                                    Product manager
# 199  Product manager                                      Product Owner
# 204  Product manager        Руководитель отдела разработки IT-проектов.
# 228  Product manager              Руководитель продуктового направления
# 319  Product manager                                 Head of HR Product
# 396  Product manager                Head of Product & Business Strategy
# 400  Product manager                                    Product manager
# 742  Product Manager           Product Owner | Руководитель направления
# 753  Product Manager                                                CPO
# 852  Product Manager                        Лидер премиальных продуктов
# 866  Product Manager                 Discovery Product Manager (BizDev)
# 911  Product manager  Head of product manager / Начальник управления...
#
#      label  id_cluster  split
# 40     0.0           6  train
# 56     0.0           6  train
# 122    0.0           6  train
# 125    0.0           6  train
# 126    0.0           6  train
# 199    0.0           6  train
# 204    0.0           6  train
# 228    0.0           6  train
# 319    0.0           6  train
# 396    0.0           6  train
# 400    0.0           6  train
# 742    0.0           6  train
# 753    0.0           6  train
# 852    0.0           6  train
# 866    0.0           6  train
# 911    0.0           6  train
#     title_vacancy                        title_resume  label  id_cluster  \
# 100   Тестировщик                             Инженер    0.0           7
# 103   Тестировщик                           Middle QA    0.0           7
# 144   Тестировщик          Специалист по тестированию    0.0           7
# 300   Тестировщик             Инженер по тестированию    0.0           7
# 313   Тестировщик                          ировщик ПО    0.0           7
# 343   Тестировщик             Инженер по эксплуатации    0.0           7
# 347   Тестировщик                         QA Engineer    0.0           7
# 350   Тестировщик               QA Engineer,  ировщик    0.0           7
# 392   Тестировщик                           QA middle    0.0           7
# 460   Тестировщик                          ировщик ПО    0.0           7
# 471   Тестировщик                          ировщик ПО    0.0           7
# 492   Тестировщик                          QA инженер    0.0           7
# 508   Тестировщик     Инженер по ручному тестированию    0.0           7
# 529   Тестировщик                                  QA    0.0           7
# 551   Тестировщик                             ировщик    0.0           7
# 566   Тестировщик  Ведущий специалист по тестированию    0.0           7
# 607   Тестировщик  Старший специалист по тестированию    0.0           7
# 683   Тестировщик  Старший специалист по тестированию    0.0           7
# 747   Тестировщик                         QA Engineer    0.0           7
#
#      split
# 100  train
# 103  train
# 144  train
# 300  train
# 313  train
# 343  train
# 347  train
# 350  train
# 392  train
# 460  train
# 471  train
# 492  train
# 508  train
# 529  train
# 551  train
# 566  train
# 607  train
# 683  train
# 747  train
#           title_vacancy                          title_resume  label  \
# 19   Frontend Developer              Senior Frontend Engineer    0.0
# 49   Frontend Developer                  Frontend-разработчик    0.0
# 184  Frontend Developer                  Frontend-разработчик    0.0
# 755  Frontend Developer                  Frontend-разработчик    0.0
# 821  Frontend Developer                  Frontend-разработчик    0.0
# 885  Frontend Developer                    Frontend developer    0.0
# 902  Frontend Developer  Frontend Developer (Javascript, Vue)    0.0
#
#      id_cluster  split
# 19            8  train
# 49            8  train
# 184           8  train
# 755           8  train
# 821           8  train
# 885           8  train
# 902           8  train
#         title_vacancy                   title_resume  label  id_cluster  split
# 151  Python Developer            Backend-разработчик    0.0           9  train
# 160  Python Developer       Python backend developer    0.0           9  train
# 346  Python Developer             Python-разработчик    0.0           9  train
# 361  Python Developer     Ведущий python Разработчик    0.0           9  train
# 495  Python Developer               Python Developer    0.0           9  train
# 702  Python Developer       Python Backend Developer    0.0           9  train
# 725  Python Developer     Python Backend разработчик    0.0           9  train
# 835  Python Developer  Главный инженер по разработке    0.0           9  train
# 857  Python Developer       Senior Python Programmer    0.0           9  train
# 889  Python Developer     Инженер-программист Python    0.0           9  train

# %% [markdown]
# # Модель определения важности слов в вакансиях и резюме

# %%
clms = ['uuid', 'description', 'title', 'vacancy_fl']
df = pd.concat([
    df_vacancy.assign(vacancy_fl=True)[clms],
    df_resume.assign(vacancy_fl=False)[clms]
], sort=False, ignore_index=True)
df['id_cluster'] = df['title'].map(title2cluster)
np.random.seed(42)
df = df.sample(frac=1).reset_index(drop=True)
df['description_tokens'] = df['description'].parallel_apply(Tokenizer(norm=True))

# получаем stop_words
# если низкий максимальный коэффициент, слово не английское, не в списке ключевых слов из резюме
key_skills = df_resume.query('key_skills != ""')['key_skills'].dropna().parallel_apply(Tokenizer(norm=True))
key_skills = set(key_skills.explode())

X = df['description_tokens'].apply(lambda x: ' '.join(x))
y = df['id_cluster']
vec = TfidfVectorizer()
clf = LogisticRegression(n_jobs=16, multi_class='ovr', random_state=42, fit_intercept=False)
vec.fit(X)
clf.fit(vec.transform(X), y)
feature_names = vec.get_feature_names_out()
coef = np.max(clf.coef_, axis=0)
pattern = re.compile(r'[a-z]+')
mask = ~np.isin(feature_names, list(set(pattern.findall(' '.join(feature_names)))))
feature_names = feature_names[mask]
coef = coef[mask]
stop_words = set(feature_names[coef < 0.01]) - key_skills
stop_words = stop_words | {'желательно'}

# токенизация
df['description_tokens'] = df['description_tokens'].apply(lambda x: ' '.join(x))
df['description_tokens_2'] = df['description'].parallel_apply(Tokenizer(norm=True, stop_words=stop_words))
df['description_tokens_2'] = df['description_tokens_2'].apply(lambda x: ' '.join(x))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=50), Label(value='0 / 50'))), HBox…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=45), Label(value='0 / 45'))), HBox…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=50), Label(value='0 / 50'))), HBox…

# %%
len(stop_words)
# Out:
# 495

# %%
stop_words
# Out:
# {'qaсессия',
#  'tна',
#  'аpache',
#  'автомобилей',
#  'автономно',
#  'авторотация',
#  'авть',
#  'адаптироваться',
#  'азбука',
#  'актуализация',
#  'акционер',
#  'альтернативный',
#  'аналогично',
#  'анимация',
#  'аннотирование',
#  'анонимизация',
#  'анонс',
#  'антарес',
#  'антипрод',
#  'аоп',
#  'аппаратура',
#  'аппликация',
#  'арихтектурный',
#  'архивный',
#  'атака',
#  'аутсорс',
#  'бакэнд',
#  'банковоска',
#  'банковской',
#  'барсума',
#  'безблокировочный',
#  'безопаасность',
#  'биржей',
#  'блокировочноить',
#  'бокс',
#  'более',
#  'бот',
#  'бронировать',
#  'букмекер',
#  'буфер',
#  'бэкенд',
#  'важной',
#  'важный',
#  'вебклиент',
#  'вендорный',
#  'вернуть',
#  'версионность',
#  'вертикальный',
#  'весь',
#  'видеоконференцсвязь',
#  'видеообучение',
#  'видеофай',
#  'вклад',
#  'вкладчик',
#  'вкус',
#  'вложенность',
#  'вмс',
#  'внесение',
#  'внутренный',
#  'внутрироссия',
#  'водоснабжение',
#  'вологда',
#  'вологодский',
#  'вопрос',
#  'восток',
#  'вставка',
#  'встраиваемый',
#  'встреча',
#  'выгода',
#  'выдернуть',
#  'выкладываться',
#  'вышеописанный',
#  'вышеперечисленный',
#  'вышеуказанный',
#  'вьюшка',
#  'вячеслав',
#  'гемблинга',
#  'генерация',
#  'геодезический',
#  'гидропневмоавтоматика',
#  'гидропривод',
#  'гит',
#  'главное',
#  'год',
#  'горизонтально',
#  'госслужащий',
#  'госучреждение',
#  'градация',
#  'грейд',
#  'грузовладелец',
#  'гуу',
#  'данной',
#  'данный',
#  'дбо',
#  'девелопер',
#  'дедлоками',
#  'демидов',
#  'джаспереть',
#  'динар',
#  'добавленноить',
#  'договориться',
#  'догонять',
#  'дополнительноить',
#  'еrp',
#  'ежедневный',
#  'еип',
#  'еисжс',
#  'ельцин',
#  'естественно',
#  'желательно',
#  'желтопёрый',
#  'журнализация',
#  'заглядывать',
#  'заданный',
#  'заключать',
#  'закончиться',
#  'залача',
#  'заполнять',
#  'запутать',
#  'зарегистрированноить',
#  'застраховать',
#  'затруднительно',
#  'затруднять',
#  'защища',
#  'звенигородский',
#  'зчб',
#  'иcпользовать',
#  'иерархический',
#  'избежание',
#  'извещение',
#  'издержка',
#  'иит',
#  'имплементировать',
#  'инвестировать',
#  'инвестиционный',
#  'инженер',
#  'инжиниринговый',
#  'инноватик',
#  'институт',
#  'интграция',
#  'интегарция',
#  'информатика',
#  'информаци',
#  'ировщик',
#  'испытатель',
#  'ифра',
#  'кабинет',
#  'кадый',
#  'казначейский',
#  'как',
#  'калифорния',
#  'кансультация',
#  'картотека',
#  'карьера',
#  'кастомизация',
#  'каталожный',
#  'катастрофа',
#  'категоризация',
#  'качество',
#  'клаб',
#  'клиентския',
#  'клиентской',
#  'колбек',
#  'коллегиальный',
#  'коммитета',
#  'компановаться',
#  'компилироваться',
#  'компилятор',
#  'конвертирование',
#  'конвертор',
#  'консюмера',
#  'контора',
#  'контрибьютить',
#  'конфиграция',
#  'кооперация',
#  'копитрейдинг',
#  'кор',
#  'коробка',
#  'корпусный',
#  'край',
#  'кризисный',
#  'криптопровай',
#  'лаконичный',
#  'лгпу',
#  'лейбл',
#  'ленинградский',
#  'либ',
#  'либо',
#  'лигамаркет',
#  'лидить',
#  'лимитировать',
#  'лихой',
#  'личный',
#  'локационный',
#  'локация',
#  'лотерейный',
#  'лотовый',
#  'луковый',
#  'магаизнов',
#  'маис',
#  'макрорегион',
#  'массивный',
#  'мгудт',
#  'менторить',
#  'месседжинг',
#  'место',
#  'мигратор',
#  'мидло',
#  'многоканальный',
#  'многомодульный',
#  'модификацией',
#  'мойсклад',
#  'мокап',
#  'мониторига',
#  'мониторить',
#  'монитронг',
#  'монотаблица',
#  'москва',
#  'мто',
#  'мудрый',
#  'мультиброкер',
#  'мягкий',
#  'наблюдать',
#  'набор',
#  'нагрузкой',
#  'наладка',
#  'нанотехнология',
#  'напоминающие',
#  'направленность',
#  'направлять',
#  'некачественный',
#  'некоммерческий',
#  'неплательщик',
#  'неструктурированный',
#  'нетология',
#  'нефтегазовый',
#  'нном',
#  'новг',
#  'новгородский',
#  'новыя',
#  'нода',
#  'ноль',
#  'нужда',
#  'нуждаемость',
#  'нуль',
#  'оracle',
#  'обеспечиваться',
#  'обработкой',
#  'общие',
#  'общий',
#  'ограничить',
#  'одиночный',
#  'однго',
#  'омс',
#  'онбордить',
#  'они',
#  'онл',
#  'особенностея',
#  'осуществление',
#  'осуществля',
#  'осуществляющие',
#  'откатить',
#  'откладка',
#  'отлавливание',
#  'отправить',
#  'отрефакторить',
#  'отстаться',
#  'отчасти',
#  'офз',
#  'оцифровка',
#  'очередть',
#  'ошибка',
#  'ошибочный',
#  'пакет',
#  'педагог',
#  'перевести',
#  'перевод',
#  'перегружать',
#  'передовемыть',
#  'переквалификация',
#  'перенаправление',
#  'перенаправлять',
#  'переработкой',
#  'перестрахование',
#  'перехватывать',
#  'перёв',
#  'петь',
#  'пиковой',
#  'пилить',
#  'план',
#  'плис',
#  'повторить',
#  'поддержкой',
#  'подмножество',
#  'подобно',
#  'подобрать',
#  'подписей',
#  'подписывание',
#  'подписывать',
#  'покупателейц',
#  'получить',
#  'пользовательския',
#  'полюс',
#  'попытка',
#  'португальский',
#  'посадочный',
#  'постбек',
#  'потоковой',
#  'почему',
#  'правов',
#  'предварительно',
#  'предикат',
#  'предстраховой',
#  'предъявляться',
#  'премиал',
#  'препрод',
#  'приблизительно',
#  'пригласить',
#  'приднестровский',
#  'прикладной',
#  'примерно',
#  'приниматься',
#  'присоедина',
#  'приход',
#  'приша',
#  'пров',
#  'проводок',
#  'продовский',
#  'продюсер',
#  'производительный',
#  'производить',
#  'производиться',
#  'проктами',
#  'промодвижок',
#  'прорефакторить',
#  'профи',
#  'профиль',
#  'пытаться',
#  'рабочий',
#  'равно',
#  'развёртывать',
#  'разный',
#  'разрабок',
#  'райфайзенбанк',
#  'ранний',
#  'раскрытие',
#  'распиливать',
#  'распредел',
#  'расценка',
#  'расширение',
#  'ргрот',
#  'реалтайм',
#  'регулятор',
#  'резюме',
#  'релиз',
#  'репликатор',
#  'репозиория',
#  'рефинансировать',
#  'росноу',
#  'роуминг',
#  'русский',
#  'ряд',
#  'самокат',
#  'самоограничение',
#  'самописновать',
#  'самостоятельно',
#  'санкция',
#  'сббол',
#  'сдэк',
#  'сентябрь',
#  'сериализатор',
#  'сетицифровой',
#  'симкарта',
#  'скачок',
#  'ским',
#  'сколково',
#  'скорринговый',
#  'слот',
#  'смигрировать',
#  'снимок',
#  'собои',
#  'собственноить',
#  'совещание',
#  'содержимое',
#  'создание',
#  'создать',
#  'сообщать',
#  'соответствующей',
#  'состояние',
#  'сотрудник',
#  'сохраниться',
#  'сохраняемость',
#  'спецалист',
#  'специальность',
#  'спецификой',
#  'сплав',
#  'сплит',
#  'спор',
#  'спорный',
#  'срок',
#  'стабилизировать',
#  'ставиться',
#  'стажёр',
#  'сталкиваться',
#  'ствовать',
#  'стейт',
#  'стерлитамакский',
#  'столкнуться',
#  'структуирование',
#  'структурирование',
#  'структуроить',
#  'сурбд',
#  'сущеcтвовать',
#  'существовавшея',
#  'существовать',
#  'существующий',
#  'схлопнуть',
#  'схлопывание',
#  'табачный',
#  'таймаут',
#  'тарифицировать',
#  'творческий',
#  'текущий',
#  'теледата',
#  'технологическия',
#  'тикетинг',
#  'тный',
#  'толстый',
#  'тонна',
#  'торрент',
#  'тотализатор',
#  'традиционно',
#  'трансфер',
#  'третим',
#  'труд',
#  'трудоустроиться',
#  'трэками',
#  'трэковы',
#  'тсб',
#  'туннель',
#  'удале',
#  'удерживать',
#  'удобно',
#  'уже',
#  'узкий',
#  'умеренный',
#  'университет',
#  'унэп',
#  'упорядоченноить',
#  'упращение',
#  'упреждающий',
#  'условие',
#  'успеваемость',
#  'устать',
#  'утилизация',
#  'утконос',
#  'учиться',
#  'факультет',
#  'филиал',
#  'финансист',
#  'формировавшие',
#  'фрд',
#  'фрейморк',
#  'фтэма',
#  'функицонал',
#  'функциональноить',
#  'фьючерский',
#  'хобби',
#  'хоститься',
#  'цасб',
#  'цупис',
#  'частное',
#  'чгу',
#  'чекер',
#  'человекочитать',
#  'череповецкий',
#  'четверть',
#  'число',
#  'чоп',
#  'шевченко',
#  'шедулера',
#  'широко',
#  'шифровать',
#  'шторка',
#  'эдельвейс',
#  'эко',
#  'экос',
#  'электроракетный',
#  'энергоустановка',
#  'эскиз',
#  'юкасса',
#  'якорный',
#  'ярославль',
#  'ярославский',
#  'ярус'}

# %%
df.head()
# Out:
#                                    uuid  \
# 0  5785c202-6744-3e1b-994a-d5bffc6aad14
# 1  dd86d509-6381-363b-9da7-46f8e3f5e91b
# 2  d15abe9e-6d82-300e-9a4d-ed18dc371ea7
# 3  7a762282-cffc-30e0-b046-44d987cedffd
# 4  34a77b82-e739-31e9-88ed-ad6ea07f1917
#
#                                          description  \
# 0  Критически важный проект, реализованный по зак...
# 1  Работаю в команде привлечения клиентов. Занима...
# 2  Курирование, сопровождение и поддержание работ...
# 3  Заказчик: ПАО « банк» Системный аналитик на пр...
# 4  1) Создание витрин данных для различных направ...
#
#                         title  vacancy_fl  id_cluster  \
# 0     Java Software Developer       False           1
# 1     Java/Kotlin разработчик       False           1
# 2        Ведущий аналитик DWH       False           4
# 3  Ведущий системный аналитик       False           2
# 4      Системный аналитик DWH       False           4
#
#                                   description_tokens  \
# 0  критически важный проект реализовать заказ пра...
# 1  работать команда привлечение клиент заниматься...
# 2  курирование сопровождение поддержание работосп...
# 3  заказчик пао банк системный аналитик проект ра...
# 4  создание витрина данные для различный направле...
#
#                                 description_tokens_2
# 0  критически проект реализовать заказ правительс...
# 1  работать команда привлечение клиент заниматься...
# 2  курирование сопровождение поддержание работосп...
# 3  заказчик пао банк системный аналитик проект ра...
# 4  витрина данные для различный направление бизне...

# %%
df.isna().sum()
# Out:
# uuid                    0
# description             0
# title                   0
# vacancy_fl              0
# id_cluster              0
# description_tokens      0
# description_tokens_2    0
# dtype: int64

# %%
X = df['description_tokens_2']
y = df['id_cluster']

vec = TfidfVectorizer()
clf = LogisticRegression(n_jobs=16, multi_class='ovr', random_state=42, fit_intercept=False)

vec.fit(X)
clf.fit(vec.transform(X), y)
feature_names = vec.get_feature_names_out()

# %%
eli5.show_weights(
    clf,
    vec=vec,
    top=(10,0),
    target_names=cluster2title[clf.classes_].values,
    feature_names=feature_names,
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Team Lead
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Java-разработчик
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Системный аналитик
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=DevOps
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Аналитик DWH
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=ETL Разработчик
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Product Manager
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Тестировщик
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Frontend Developer
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Python Developer
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.465
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reso
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.429
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         programmer
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.388
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bamboo
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.350
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         otus
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.342
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         группа
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.341
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         comunda
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.338
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         coroutines
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.335
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         бастион
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.320
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         стрим
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.320
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         включая
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 96.49%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 1172 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 11994 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#                         </td>
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales,

# %%
# i = np.random.randint(0,len(df)) #23931

# print(df.loc[i, 'title'])
# print()
# print(df.loc[i, 'uuid'])
# print(df.loc[i, 'vacancy_fl'])

# eli5.show_prediction(
#     clf, 
#     df.loc[i, 'description_tokens'], 
#     vec=vec, 
#     feature_names=feature_names, 
#     targets=[df.loc[i, 'id_cluster']],
#     target_names=clf.classes_
# )

# %%
class SorterDescription:
    def __init__(self, clf, vec, sentenizer, tokenizer):
        self._clf = clf
        self._vec = vec
        self._sentenizer = sentenizer
        self._tokenizer = tokenizer
        
    def __call__(self, description, id_cluster):
        coef = self._clf.coef_[self._clf.classes_ == id_cluster].T
        # coef[coef < 0] = 0

        sents = np.array(self._sentenizer(description))
        sents_tokenized = np.array([' '.join(self._tokenizer(text)) for text in sents])
        X = self._vec.transform(sents_tokenized)
        weight = X @ coef
        ids = np.argsort(-weight.squeeze())
        description_sorted = ' '.join(sents[ids])
        return description_sorted
    
    
class Tagger:
    def __init__(self, clf, vec, tokenizer):
        self._clf = clf
        self._vec = vec
        self._tokenizer = tokenizer
        
    def __call__(self, description, id_cluster, k=0.1):
        coef = self._clf.coef_[self._clf.classes_ == id_cluster].squeeze()
        
        sents = [' '.join(self._tokenizer(description))]                 
        X = self._vec.transform(sents).toarray().squeeze()
        mask = (X != 0) & (coef > 0)
        if mask.sum():
            weights = coef[mask] * X[mask]

            tokens = self._vec.get_feature_names_out()
            tokens = tokens[mask]

            ids = np.argsort(-weights)
            tokens = tokens[ids]
            weights = weights[ids]
            tokens = list(tokens[weights > np.quantile(weights, k)])
        else:
            tokens = []
        return tokens

sort_description = SorterDescription(clf, vec, sentenizer, Tokenizer(norm=True))
get_tags = Tagger(clf, vec, Tokenizer(norm=True))

# %%
df_vacancy['description_tokens'] = df_vacancy['description'] \
    .parallel_apply(Tokenizer(norm=True)) \
    .apply(lambda x: ' '.join(x))

df_resume['description_tokens'] = df_resume['description'] \
    .parallel_apply(Tokenizer(norm=True)) \
    .apply(lambda x: ' '.join(x))

df_vacancy['id_cluster'] = df_vacancy['title'].map(title2cluster)
df_resume['id_cluster'] = df_resume['title'].map(title2cluster)

df_vacancy['description_sorted'] = df_vacancy.parallel_apply(lambda x: sort_description(x.description, x.id_cluster), axis=1)
df_resume['description_sorted'] = df_resume.parallel_apply(lambda x: sort_description(x.description, x.id_cluster), axis=1)

df_vacancy['tags'] = df_vacancy.parallel_apply(lambda x: get_tags(x.description, x.id_cluster), axis=1)
df_resume['tags'] = df_resume.parallel_apply(lambda x: get_tags(x.description, x.id_cluster), axis=1)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=2), Label(value='0 / 2'))), HBox(c…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=49), Label(value='0 / 49'))), HBox…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=2), Label(value='0 / 2'))), HBox(c…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=49), Label(value='0 / 49'))), HBox…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=2), Label(value='0 / 2'))), HBox(c…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=49), Label(value='0 / 49'))), HBox…

# %%
i = np.random.randint(0,len(df_vacancy)) #23931

print(df_vacancy.loc[i, 'title'])
print()
print(df_vacancy.loc[i, 'uuid'])

eli5.show_prediction(
    clf, 
    df_vacancy.loc[i, 'description_tokens'], 
    vec=vec, 
    feature_names=feature_names, 
    targets=[df_vacancy.loc[i, 'id_cluster']],
    target_names=clf.classes_
)
# Out:
# Frontend Developer
#
# 259bf318-e6a7-3b6c-93f9-e1804a89ee63
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=8
#
# </b>
#
#
#     (probability <b>0.188</b>, score <b>-1.330</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.330
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 94.99%); opacity: 0.81" title="0.005">бренд</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.09%); opacity: 0.80" title="0.002">одежда</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.55%); opacity: 0.81" title="0.004">аксессуар</span><span style="opacity: 0.80"> создать год </span><span style="background-color: hsl(120, 100.00%, 95.07%); opacity: 0.81" title="0.005">наш</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.58%); opacity: 0.80" title="-0.002">магазин</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.22%); opacity: 0.81" title="0.003">представить</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.34%); opacity: 0.81" title="-0.005">россия</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.79%); opacity: 0.80" title="0.001">снг</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.17%); opacity: 0.82" title="-0.010">также</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.05%); opacity: 0.81" title="-0.005">онлайн</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.87%); opacity: 0.81" title="0.003">доставка</span><span style="opacity: 0.80"> весь </span><span style="background-color: hsl(120, 100.00%, 99.66%); opacity: 0.80" title="0.000">мир</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.07%); opacity: 0.81" title="0.005">наш</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.12%); opacity: 0.80" title="0.001">успех</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.98%); opacity: 0.80" title="0.003">заключаться</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.86%); opacity: 0.81" title="0.005">слаженный</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.88%); opacity: 0.80" title="-0.002">командный</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 86.08%); opacity: 0.84" title="-0.022">работа</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.51%); opacity: 0.82" title="-0.011">что</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.93%); opacity: 0.81" title="-0.005">позволять</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.99%); opacity: 0.81" title="0.005">бренд</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.69%); opacity: 0.80" title="-0.002">создавать</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.42%); opacity: 0.81" title="0.003">востребовать</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.02%); opacity: 0.80" title="0.001">качественный</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 86.64%); opacity: 0.84" title="-0.021">продукт</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.37%); opacity: 0.80" title="0.001">всегда</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.86%); opacity: 0.81" title="0.005">рада</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.22%); opacity: 0.80" title="-0.001">знакомство</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.44%); opacity: 0.83" title="-0.013">новый</span><span style="opacity: 0.80"> </span><span style="backgro ...

# %%
i = np.random.randint(0,len(df_resume)) #23931

print(df_resume.loc[i, 'title'])
print()
print(df_resume.loc[i, 'uuid'])

eli5.show_prediction(
    clf, 
    df_resume.loc[i, 'description_tokens'], 
    vec=vec, 
    feature_names=feature_names, 
    targets=[df_resume.loc[i, 'id_cluster']],
    target_names=clf.classes_
)
# Out:
# Senior Software Developer Team Lead
#
# 9fe9cded-6120-384e-8f9a-96ce33bc99dd
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
#
#     (probability <b>0.443</b>, score <b>-0.068</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.068
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 98.11%); opacity: 0.80" title="-0.001">разработка</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.10%); opacity: 0.82" title="-0.006">корпоративный</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.02%); opacity: 0.82" title="0.009">web</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.47%); opacity: 0.87" title="0.026">приложение</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.88%); opacity: 0.82" title="0.006">интеграционный</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.73%); opacity: 0.80" title="-0.001">система</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.63%); opacity: 0.81" title="0.002">для</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.24%); opacity: 0.81" title="0.005">государственный</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.13%); opacity: 0.80" title="-0.000">структура</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.10%); opacity: 0.86" title="-0.022">управление</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.69%); opacity: 0.83" title="-0.011">команда</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.11%); opacity: 0.80" title="-0.001">разработка</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.47%); opacity: 0.81" title="-0.003">чел</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.87%); opacity: 0.82" title="0.009">зависимость</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.17%); opacity: 0.81" title="0.005">проект</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.15%); opacity: 0.82" title="-0.006">общение</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 80.37%); opacity: 0.87" title="-0.027">заказчик</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.47%); opacity: 0.80" title="0.000">оценка</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.11%); opacity: 0.80" title="0.002">трудозатрата</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.17%); opacity: 0.81" title="0.005">проект</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.21%); opacity: 0.86" title="-0.021">составление</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.35%); opacity: 0.81" title="0.005">релизный</span><span style="opacity: 0.80"> план </span><span style="background-color: hsl(0, 100.00%, 89.01%); opacity: 0.83" title="-0.012">построение</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.88%); opacity: 0.82" title="0.008">архитектура</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.47%); opacity: 0.87" title="0.026">приложение</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.67%); opacity: 0.87" title="0.024">рефакторинг</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.77%); opacity: 0.83" title="-0.011">участие</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.17%); opacity: 0.81" title="0.005">проект</span><span style="opacity: 0.80"> качество </span><span style="background-color: hsl(120, 100.00%, 95.50%); opacity: 0.81" title="0.003">старший</span><span  ...

# %%
i = np.random.randint(0,len(df_vacancy))

description = df_vacancy.loc[i]['description']
description_sorted = df_vacancy.loc[i]['description_sorted']
title = df_vacancy.loc[i]['title']
id_cluster = df_vacancy.loc[i]['id_cluster']

print(title)
print()
print(*sentenizer(description), sep='\n')
print()
print(*sentenizer(description_sorted), sep='\n')
print()
print(get_tags(description, id_cluster, k=0.1))
# Out:
# Product Manager
#
# Февраль 2024г, профили в работе: B2B - опыт в финтехе 1)  две вакансии сюда немного разные по профилю ( ЛК - привлечение B2B партнёров и.
# ВЭД ) __________________________________________________________________________ B2B - можно без финтех опыта 2) - лояльность (B2B) , есть еще одна позиция на эквайринг (интернет, не торговый) , но там пока описание не сделали еще (то есть здесь 2 позиции тоже) ____________________________________________________________________________ B2C - желателен опыт с маркетплейсами 3).
# Подробнее про B2C (про нее не успели вчера).
# По требованиям +- тоже самое только очень важен опыт работы с маркетплейсами.
# Продукт: Кредитование внутри маркетплейса (рассрочка) - кредитования физ лиц (покупателей маркетплейса).
# Задача: построить/проработать стратегию продукта (важен ретеншн и прирост новых клиентов на направление).
# Направление у нас новое.
# Все члены команды важные для создания продукта +- уже есть или будут в ближ время, но сейчас самое главное - проработка стратегии.
# Есть метрика бизнесовая, которую надо придумать как вырастить.
# Продукт уже имеет неплохую долю внутри, продукт имеет неплохой ретеншн, продукт с достаточно большим количеством сценариев.
# Ключевой портфель в кредитных продуктах.
# Важно: чтобы был опыт развития продукта с нуля.
# Чтобы человек был структурным, любил схемы, ясно излагал бы свои мысли.
# Имел бы баланс между действиями и анализом.
# Костюмер девелопмент, работа с макетами и тд.
# Важна амбициозность ____________________________________________________________________   Банк для бизнеса — одно из ключевых направлений   Fintech.
# Мы разработали банк с нуля на собственной платформе, что дает максимальную гибкость, быструю скорость развития и независимость от сторонних вендоров.
# Банк глубоко интегрирован в маркетплейс, а команда отлично разбирается в торговле.
# Как результат — успешный запуск и стремительный рост клиентской базы, а в ближайшее время планируем вывести банк в топ по.
# России.
# Как продавать:   - стартап внутри основной компании, имеющий поддержку крупной компании (3к человек, 500 в IT).
# Планы на ближайшие 1-1,5г. - вырасти х2 в It, глобально же за 2-3г. войти в топ-5 It-банков.
# РФ, поэтому рост и развитие сейчас основная цель.
#
# Продукт уже имеет неплохую долю внутри, продукт имеет неплохой ретеншн, продукт с достаточно большим количеством сценариев.
# Ключевой портфель в кредитных продуктах.
# Задача: построить/проработать стратегию продукта (важен ретеншн и прирост новых клиентов на направление).
# Продукт: Кредитование внутри маркетплейса (рассрочка) - кредитования физ лиц (покупателей маркетплейса).
# Как результат — успешный запуск и стремительный рост клиентской базы, а в ближайшее время планируем вывести банк в топ по.
# Есть метрика бизнесовая, которую надо придумать как вырастить.
# Все члены команды важные для создания продукта +- уже есть или будут в ближ время, но сейчас самое главное - проработка стратегии.
# РФ, поэтому рост и развитие сейчас основная цель.
# Важно: чтобы был опыт развития продукта с нуля.
# Планы на ближайшие 1-1,5г. - вырасти х2 в It, глобально же за 2-3г. войти в топ-5 It-банков.
# Подробнее про B2C (про нее не успели вчера).
# России.
# Банк глубоко интегрирован в маркетплейс, а команда отлично разбирается в торговле.
# Мы разработали банк с нуля на собственной платформе, что дает максимальную гибкость, быструю скорость развития и независимость от сторонних вендоров.
# Чтобы человек был структурным, любил схемы, ясно излагал бы свои мысли.
# ВЭД ) __________________________________________________________________________ B2B - можно без финтех опыта 2) - лояльность (B2B) , есть еще одна позиция на эквайринг (интернет, не торговый) , но там пока описание не сделали еще (то есть здесь 2 позиции тоже) ____________________________________________________________________________ B2C - желателен опыт с маркетплейсами 3).
# Направление у нас новое.
# Важна амбициозность ____________________________________________________________________   Банк для бизнеса — одно из ключевых направлений   Fintech.
# Февраль 2024г, профили в работе: B2B - опыт в финтехе 1)  две вакансии сюда немного разные по профилю ( ЛК - привлечение B2B партнёров и.
# Костюмер девелопмент, работа с макетами и тд.
# Как продавать:   - стартап внутри основной компании, имеющий поддержку крупной компании (3к человек, 500 в IT).
# Имел бы баланс между действиями и анализом.
# По требованиям +- тоже самое только очень важен опыт работы с маркетплейсами.
#
# ['продукт', 'стратегия', 'маркетплейс', 'развитие', 'рост', 'есть', 'запуск', 'топ', 'метрика', 'ключевой', 'привлечение', 'доля', 'ретеншн', 'неплохой', 'направление', 'лояльность', 'что', 'тоже', 'вырастить', 'партнёр', 'fintech', 'внутри', 'планировать', 'вырасти', 'войти', 'человек', 'стартап', 'вывести', 'самый', 'глобально', 'успешный', 'можно', 'финтех', 'иметь', 'рассрочка', 'продавать', 'ближ', 'амбициозность', 'глубоко', 'костюмер', 'стремительный', 'отлично', 'бизнесовый', 'вчера', 'независимость', 'гибкость', 'сделать', 'вендор', 'эквайринг', 'придумать', 'любить', 'результат', 'февраль', 'кредитование', 'прирост', 'девелопмент', 'максимальный', 'чтобы', 'структурный', 'успеть', 'подробный', 'построить', 'ясно', 'покупатель', 'два', 'действие', 'пока', 'цель', 'сюда', 'физ', 'надо', 'здесь', 'вэд', 'вакансия', 'желательный']

# %%
i = np.random.randint(0,len(df_resume))

description = df_resume.loc[i]['description']
description_sorted = df_resume.loc[i]['description_sorted']
title = df_resume.loc[i]['title']
id_cluster = df_resume.loc[i]['id_cluster']

print(title)
print()
print(*sentenizer(description), sep='\n')
print()
print(*sentenizer(description_sorted), sep='\n')
print()
print(get_tags(description, id_cluster, k=0.1))
# Out:
# Системный аналитик WFM
#
# Достижения: Для компании.
# Глобус сделал work around файловый обмен данных между BI и WFM.
# В данном интерфейсе используется библиотеки анализа данных на python для преобразования данных в формат WFM.
# Данное work around решение, уменьшило время подготовки и загрузки данных в систему по 1 гипермаркету с 21 дня до 4х. Также на базе данного решения был реализован ETL процесс с ежедневной загрузкой данных в систему.
# Также была разработана модель прогноза оборота в рублях и штуках, с детализацией по дням по всем магазинам компании.
# При оценки произвольных периодов на уровне дня по всем магазинам взвешенная абсолютная ошибка составила 8% Обязанности: - Работа с бизнес требованиями: анализ, уточнение и согласование;
# - Оценка технических альтернатив для бизнес требований;
# - Составление технических заданий, совместно с разработчиками, аналитиками бизнес процессов, архитекторами и заказчиками, также участие в составлении технических спецификаций для обмена данными;
# - Взаимодействие с: вендором, технической поддержкой, заказчиками, бизнес аналитиками и аналитиками бизнес процессов;
# - Составление и поддержка функциональной и технической документацию по направлению: техническое задание, протокол настроек, пользовательской документации;
# - Самостоятельно и командное тестирование новых функций: функциональное, интеграционное и регрессионное тестирование;
# - Участие в проектах автоматизации, как функциональный эксперт направления;
# - Анализ проблем функционирования и решение инцидентов в соответствии с SLA;
# - Консультирование и техническая поддержка пользователей;
# - Взаимодействие с. Центром компетенции SAP и другими.
# ИТ командами..
# Ведение блока проекта work force management (WFM): - Прогнозирование - Анализ ключевых показателей бизнеса с целью выявления закономерностей и взаимосвязей: продажи, трафик, средний чек, продуктовый микс и т.п. - Факторный и корреляционный анализ динамики ключевых показателей бизнеса, которые влияют на эффективность распределения трудовых ресурсов;
# - Разработка и подтверждение гипотез в части аналитической работы с блоком WFM;
# - Участие в разработке / поддержке моделей прогнозирования и планирования для блока WFM - Ad-hoc аналитика для смежных отделов по работе с WFM - Подготовка регулярных аналитических презентаций и рекомендаций для руководства компании - Разработка и поддержка динамических дэшбордов по анализу эффективности работы блока WFM - Участие в прочих проектах компании в качестве аналитической функции..
# Достижения: Для контактного центра.
# Маркета составил модель планирования обращений.
# Модель базируется на тенденциях и сезонностях.
# Модель учитывала и выравнивали аномалии в фактических данных за прошлый период.
# Также разработал отдельную модель для специальных событиях: распродажи, праздники, рабочие субботы и т.д.
# При оценки произвольных периодов на уровне дня взвешенная абсолютная ошибка составила 7%, на уровне часа 13% соответственно.
# Обязанности: - Анализ нагрузки за прошедший период по входящим и исходящим контактам с клиентами: звонки, чаты, письма, заявки и пр.;
# - Построение краткосрочных и среднесрочных прогнозов по операциям с детализацией до: часа, дня, месяца;
# - Планирование графиков работы и перерывов подразделений службы поддержки по результатам прогноза нагрузки на будущие периоды;
# - Анализ точности планирования и подготовка аналитических отчётов по итогам отчётного периода;
# - Анализ операционных управленческих затрат, расчёты себестоимости выполнения операций;
# - Финансовые расчёты, для обоснования экономической эффекта при внедрении новых или изменении текущих процессов.
# Достижения: Для бренда.
# Эльдорадо, разработал модель расчёта численности линейного персонала.
# Экономический эффект, после распределение штата согласно расчёту модели: экономия фонда оплаты труда на 5%.
# Обязанности: - Операционное планирование численности розничных магазинов;
# - Бюджетное планирование численности розничных магазинов;
# - Составление, актуализация и поддержка методологии и модели для расчета численности персонала;
# - Поддержка бизнес-процессов розничных магазинов в части планирования численности, графиков работы и штатного расписания;
# - Составление методологии и поддержка процесса классификации магазинов и контроля организационных структур;
# - Обучал руководителей подразделений: методологии планирования численности, правилам формирования графиков работы, категорирования магазинов;
# - Поддержка функционирования и проведение доработок, в части управления персоналом;
# - Участие в проектах, направленных на снижение фонда оплаты труда и улучшение процессов работы внутреннего персонала компании..
# MS Excel, MS PowerPoint, WFM, SQL, Workforce management, Python, pandas, numpy, CLI, VBA, seaborn, mathplotlib, SAP, PostgreSQL, MS SQL, Git, Tableau, Datalens, Scikit-learn, Business English, Прогнозирование, Кадровое планирование, Краткосрочное бюджетирование и планирование, Сбор и анализ информации.
# Академия.
# Риторис.
# ООО "МВМ".
# Московский финансово-промышленный университет "Синергия", Москва.
# ООО "Яндекс.Маркет".
# Прикладная.
# Информатика.
# Академия.
# Риторис.
# Prostopreza.ru.
# Информационный менеджмент.
# Апекс.
# Берг.
# Контакт-Центр.
# Консалтинг.
# Риторика & Ораторское.
# Исскуство.
# Искусство презентации.
# Workforce Management для.
# Контактных.
# Центров в деталях.
# Высшее..
# ['Русский', 'Английский', 'Грузинский']
#
# - Взаимодействие с: вендором, технической поддержкой, заказчиками, бизнес аналитиками и аналитиками бизнес процессов;
# - Составление технических заданий, совместно с разработчиками, аналитиками бизнес процессов, архитекторами и заказчиками, также участие в составлении технических спецификаций для обмена данными;
# - Составление и поддержка функциональной и технической документацию по направлению: техническое задание, протокол настроек, пользовательской документации;
# - Оценка технических альтернатив для бизнес требований;
# При оценки произвольных периодов на уровне дня по всем магазинам взвешенная абсолютная ошибка составила 8% Обязанности: - Работа с бизнес требованиями: анализ, уточнение и согласование;
# - Анализ точности планирования и подготовка аналитических отчётов по итогам отчётного периода;
# Ведение блока проекта work force management (WFM): - Прогнозирование - Анализ ключевых показателей бизнеса с целью выявления закономерностей и взаимосвязей: продажи, трафик, средний чек, продуктовый микс и т.п. - Факторный и корреляционный анализ динамики ключевых показателей бизнеса, которые влияют на эффективность распределения трудовых ресурсов;
# - Анализ проблем функционирования и решение инцидентов в соответствии с SLA;
# - Составление методологии и поддержка процесса классификации магазинов и контроля организационных структур;
# Искусство презентации.
# - Анализ операционных управленческих затрат, расчёты себестоимости выполнения операций;
# Контакт-Центр.
# - Составление, актуализация и поддержка методологии и модели для расчета численности персонала;
# - Обучал руководителей подразделений: методологии планирования численности, правилам формирования графиков работы, категорирования магазинов;
# Эльдорадо, разработал модель расчёта численности линейного персонала.
# ООО "Яндекс.Маркет".
# - Поддержка бизнес-процессов розничных магазинов в части планирования численности, графиков работы и штатного расписания;
# - Взаимодействие с. Центром компетенции SAP и другими.
# - Бюджетное планирование численности розничных магазинов;
# ООО "МВМ".
# - Финансовые расчёты, для обоснования экономической эффекта при внедрении новых или изменении текущих процессов.
# Центров в деталях.
# Консалтинг.
# Модель базируется на тенденциях и сезонностях.
# Обязанности: - Операционное планирование численности розничных магазинов;
# Экономический эффект, после распределение штата согласно расчёту модели: экономия фонда оплаты труда на 5%.
# Апекс.
# Берг.
# Обязанности: - Анализ нагрузки за прошедший период по входящим и исходящим контактам с клиентами: звонки, чаты, письма, заявки и пр.;
# - Консультирование и техническая поддержка пользователей;
# При оценки произвольных периодов на уровне дня взвешенная абсолютная ошибка составила 7%, на уровне часа 13% соответственно.
# Контактных.
# - Участие в разработке / поддержке моделей прогнозирования и планирования для блока WFM - Ad-hoc аналитика для смежных отделов по работе с WFM - Подготовка регулярных аналитических презентаций и рекомендаций для руководства компании - Разработка и поддержка динамических дэшбордов по анализу эффективности работы блока WFM - Участие в прочих проектах компании в качестве аналитической функции..
# Риторис.
# Риторис.
# Риторика & Ораторское.
# Исскуство.
# Prostopreza.ru.
# Московский финансово-промышленный университет "Синергия", Москва.
# Информатика.
# Прикладная.
# - Участие в проектах автоматизации, как функциональный эксперт направления;
# Маркета составил модель планирования обращений.
# MS Excel, MS PowerPoint, WFM, SQL, Workforce management, Python, pandas, numpy, CLI, VBA, seaborn, mathplotlib, SAP, PostgreSQL, MS SQL, Git, Tableau, Datalens, Scikit-learn, Business English, Прогнозирование, Кадровое планирование, Краткосрочное бюджетирование и планирование, Сбор и анализ информации.
# Академия.
# Академия.
# Модель учитывала и выравнивали аномалии в фактических данных за прошлый период.
# - Планирование графиков работы и перерывов подразделений службы поддержки по результатам прогноза нагрузки на будущие периоды;
# ['Русский', 'Английский', 'Грузинский'] - Участие в проектах, направленных на снижение фонда оплаты труда и улучшение процессов работы внутреннего персонала компании..
# - Построение краткосрочных и среднесрочных прогнозов по операциям с детализацией до: часа, дня, месяца;
# Достижения: Для контактного центра.
# Информационный менеджмент.
# Также была разработана модель прогноза оборота в рублях и штуках, с детализацией по дням по всем магазинам компании.
# Workforce Management для.
# - Разработка и подтверждение гипотез в части аналитической работы с блоком WFM;
# Глобус сделал work around файловый обмен данных между BI и WFM.
# Также разработал отдельную модель для специальных событиях: распродажи, праздники, рабочие субботы и т.д.
# Достижения: Для бренда.
# - Поддержка функционирования и проведение доработок, в части управления персоналом;
# В данном интерфейсе используется библиотеки анализа данных на python для преобразования данных в формат WFM.
# Данное work around решение, уменьшило время подготовки и загрузки данных в систему по 1 гипермаркету с 21 дня до 4х. Также на базе данного решения был реализован ETL процесс с ежедневной загрузкой данных в систему.
# Достижения: Для компании.
# Высшее..
# ИТ командами..
# - Самостоятельно и командное тестирование новых функций: функциональное, интеграционное и регрессионное тестирование;
#
# ['анализ', 'бизнес', 'составление', 'процесс', 'модель', 'требование', 'технический', 'wfm', 'заказчик', 'подготовка', 'период', 'численность', 'документация', 'планирование', 'задание', 'центр', 'презентация', 'блок', 'ооо', 'персонал', 'ведение', 'спецификация', 'экономический', 'сбор', 'формирование', 'руководство', 'аналитик', 'решение', 'взаимодействие', 'контроль', 'согласование', 'вендор', 'эффективность', 'выявление', 'внедрение', 'доработка', 'система', 'english', 'workforce', 'отдел', 'изменение', 'консультирование', 'around', 'участие', 'прогноз', 'контакт', 'архитектор', 'смежный', 'совместно', 'управленческий', 'краткосрочный', 'сезонность', 'промышленный', 'риторис', 'абсолютный', 'tableau', 'консалтинг', 'business', 'кадровый', 'контактный', 'функциональный', 'берг', 'апекс', 'powerpoint', 'sla', 'уточнение', 'произвольный', 'средний', 'эффект', 'влиять', 'яндекс', 'отчёт', 'фактический', 'факторный', 'подтверждение', 'себестоимость', 'трудовой', 'финансовый', 'пользовательский', 'аналитика', 'график', 'искусство', 'розничный', 'оценка', 'соответствие', 'после', 'магазин', 'входящий', 'методология', 'динамика', 'итог', 'месяц', 'обоснование', 'интерфейс', 'sap', 'эксперт', 'взвесить', 'будущий', 'среднесрочный', 'распределение', 'исходить', 'уровень', 'отчётный', 'datalens', 'ресурс', 'суббота', 'эльдорадо', 'prostopreza', 'mathplotlib', 'force', 'штатный', 'выравнивать', 'альтернатива', 'ораторский', 'микс', 'глобус', 'грузинский', 'мвм', 'корреляционный', 'риторика', 'категорирование', 'распродажа', 'исскуство', 'перерыв', 'гипермаркет', 'прочий', 'формат', 'при', 'прошедший', 'финансово', 'протокол', 'трафик']

# %%
plot_wordcloud(df_vacancy['tags'].explode())

# %% [markdown]
# # Подготовка данных для финальной модели

# %%
clms = ['uuid', 'description_sorted', 'tags', 'title']
df = df_pairs \
    .merge(df_vacancy[clms], left_on='uuid_vacancy', right_on='uuid') \
    .drop('uuid', axis=1) \
    .merge(df_resume[clms], left_on='uuid_resume', right_on='uuid', suffixes=['_vacancy', '_resume']) \
    .drop('uuid', axis=1)

df['id_cluster'] = df['title_vacancy'].map(title2cluster)
np.random.seed(42)
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.to_pickle(f'{DATA_PROCESSED}/df.pickle')

# %%
df.head()
# Out:
#                            uuid_vacancy                           uuid_resume  \
# 0  779f3a59-206a-3241-adc4-d7db504f960b  2b5ad5e1-1f31-3f3f-8a66-43cd89233672
# 1  61a5a940-c9f2-3f9f-bbda-9cf735697878  843b47a5-ee84-3fec-bb03-f86b986e2a55
# 2  b2315867-73a2-3d43-acac-cbb92bd793b3  4f4ca6da-a023-3dc0-9e11-1378ff89109c
# 3  dfaf7cc8-3726-361e-b7cf-6d9746d6bf77  2e38eb42-6f68-3635-899b-aa2b8f6b0620
# 4  aecfdaf6-e12c-3309-8f1b-157028ef63d5  27427f04-a737-3679-a39c-abe5e8b13dba
#
#    label  split                         description_sorted_vacancy  \
# 0    0.0  train  Опыт разработки на Java от 3 лет. Опыт коммерч...
# 1    0.0  train  Стрим, как. Более 10 команд в стриме. Решать а...
# 2    0.0    val  Gradle/Maven; - Понимание Reactive Spring (Spr...
# 3    0.0  train  Требования для QA: Понимание теории тестирован...
# 4    0.0  train  Опыт разработки на Java с использованием техно...
#
#                                         tags_vacancy  \
# 0  [java, spring, boot, kafka, kotlin, docker, оп...
# 1  [стрим, руб, прекрасный, принятие, чувство, са...
# 2  [spring, java, maven, kafka, приложение, rabbi...
# 3  [тестирование, регрессионный, фкр, тестовый, к...
# 4  [java, spring, boot, maven, hibernate, junit, ...
#
#                                        title_vacancy  \
# 0                Java разработчик команда Инвестиции
# 1                                   ИТ-Лидер команды
# 2  Senior Java-разработчик проект брокерское обсл...
# 3                                        Тестировщик
# 4                                   Java-разработчик
#
#                            description_sorted_resume  \
# 0  Стек ядра: Java 1.8, Spring(DI, MVC), Hibernat...
# 1  Oracle Certified Associate - Java SE8 Programm...
# 2  Java, SQL, Java Spring Framework, Apache Kafka...
# 3  SQL, PostgreSQL, Postman, Android studio, Char...
# 4  Стек технологий: Java 8, Spring Framework, Hib...
#
#                                          tags_resume  \
# 0  [java, spring, kotlin, boot, hibernate, mongod...
# 1  [programmer, arm, programming, principles, acc...
# 2  [spring, java, apache, boot, рефакторинг, hibe...
# 3  [тестирование, ирование, дефект, кейс, регресс...
# 4  [spring, java, приложение, boot, hibernate, ka...
#
#                        title_resume  id_cluster
# 0  Начальник отдела java разработки           1
# 1                         Lead Java           0
# 2          Старший Java-разработчик           1
# 3                       QA Engineer           7
# 4             Senior Java Developer           1
